# %% [markdown]
# ## Setup and Dependencies

# %%
import numpy as np
import pandas as pd
from pandas.tseries.holiday import USFederalHolidayCalendar
from matplotlib import pyplot as plt
from fredapi import Fred
from dolo import *
import os
from statsmodels.regression.linear_model import OLS
from pandas_datareader import data as pdr
from statsmodels.tsa.filters.hp_filter import hpfilter
import yfinance as yf
import datetime as dt

# %% [markdown]
# ## Model Setup

# %%
yaml_rbc = """
name: Real Business Cycle

symbols:

   exogenous: [e_z]
   states: [z, k]
   controls: [n, i]
   parameters: [beta, sigma, eta, chi, delta, alpha, rho, zbar, sig_z]

definitions: |
    y[t] = exp(z[t])*k[t]^alpha*n[t]^(1-alpha)
    c[t] = y[t] - i[t]
    rk[t] = alpha*y[t]/k[t]
    w[t] = (1-alpha)*y[t]/n[t]

equations:

    arbitrage: |
        chi*n[t]^eta*c[t]^sigma - w[t]                     ⟂ 0.0 <= n[t] <= inf
        1 - beta*(c[t]/c[t+1])^(sigma)*(1-delta+rk[t+1])   ⟂ -inf <= i[t] <= inf

    transition: |
        z[t] = rho*z[t-1] + e_z
        k[t] = (1-delta)*k[t-1] + i[t-1]

calibration:

    # parameters
    beta : 0.99
    phi: 1
    delta : 0.025
    alpha : 0.33
    rho : 0.8
    sigma: 5
    eta: 1
    sig_z: 0.016
    zbar: 0
    chi : w/c^sigma/n^eta
    c_i: 1.5
    c_y: 0.5
    e_z: 0.0
    n: 0.33
    z: zbar
    rk: 1/beta-1+delta
    w: (1-alpha)*exp(z)*(k/n)^(alpha)
    k: n/(rk/alpha)^(1/(1-alpha))
    y: exp(z)*k^alpha*n^(1-alpha)
    i: delta*k
    c: y - i
    V: log(c)/(1-beta)
    u: c^(1-sigma)/(1-sigma) - chi*n^(1+eta)/(1+eta)
    m: beta/c^sigma*(1-delta+rk)
    kss: 10

exogenous: !UNormal
    sigma: 0.01

domain:
    z: [-2*sig_z/(1-rho^2)^0.5,  2*sig_z/(1-rho^2)^0.5]
    k: [ kss*0.5, kss*1.5]

options:
    grid: !Cartesian
        n: [100, 100]
    discrete_choices: [n]
"""

file_path = "yamlDSGE/rbc.yaml"

os.makedirs(os.path.dirname(file_path), exist_ok=True)

with open(file_path, "w", encoding="utf-8") as f:
    f.write(yaml_rbc)

print(f"RBC model saved to {file_path}")
# Out:
# RBC model saved to yamlDSGE/rbc.yaml

# %% [markdown]
# ## Model Execution

# %%
class Modifications():
    def __init__(self):
        self.months_in_quarter = 3

    def convert_years_to_quarters(self, length_years):
        return length_years * 4
    
    def convert_years_to_months(self, length_years):
        return length_years * 12

    def get_shifted_date(self, date_input, date_offset_months, direction="backwards"):
        if direction == "backwards":
            date_offset_months *= -1
        
        shifted_date = (
            ((pd.tseries.offsets.BMonthBegin().rollback(date_input)) + pd.tseries.offsets.DateOffset(months=date_offset_months)) 
            + pd.tseries.offsets.BMonthEnd()
        ).date()
    
        return shifted_date
    
    def add_buffer_for_start_offset(self, offset_months):
        return offset_months + 3 # Productivity and GDP starts need a buffer of 1 quarter, as the quarterly index is as of the start of the quarter rather than the end of the quarter

# %%
class Data(Modifications):
    def  __init__(self, data_length_years_max, horizon_start_in, horizon_end_in):
        Modifications.__init__(self)
        self.data_length_years_max = data_length_years_max
        self.data_length_quarters_max = self.convert_years_to_quarters(self.data_length_years_max)
        self.data_length_months_max = self.convert_years_to_months(self.data_length_years_max)
        
        self.horizon_start_in = horizon_start_in
        self.horizon_end_in = horizon_end_in
        self.horizon_start = self.convert_str_date_to_dt(self.horizon_start_in)
        self.horizon_end = self.convert_str_date_to_dt(self.horizon_end_in)
        self.date_start_gdp = self.get_shifted_date(self.horizon_start, self.add_buffer_for_start_offset(self.data_length_months_max)) # Data starts 10 years prior to window start
        self.date_start_prod = self.get_shifted_date(self.date_start_gdp, self.months_in_quarter) # Data starts one quarter prior to GDP data for next-period forecasting
        self.date_end_prod = self.get_shifted_date(self.horizon_end, self.months_in_quarter) # Data ends one quarter before window end as the final forecast must be of the window end date
        # self.horizon_start_prod = self.get_shifted_date(self.horizon_start, self.months_in_quarter) # Window starts one quarter prior to GDP data for next-period forecasting
        self.date_end_asset = self.get_shifted_date(self.horizon_end, self.months_in_quarter, "forwards") + pd.tseries.offsets.DateOffset(days=1) # end date in yahoo finance query is exclusive so extend by 1 day

        self.prod = self.pull_data_productivity()
        self.gdp = self.pull_data_gdp()
        self.asset_sp500 = self.pull_asset("^GSPC")
        self.asset_dow = self.pull_asset("^DJI")
        self.holidays = self.get_holidays()

    def convert_str_date_to_dt(self, date_in):
        return dt.date(int(date_in[:4]), int(date_in[5:7]), int(date_in[8:]))

    def convert_fred_index_to_qe(self, index_dates):
        return [date_i.date() for date_i in index_dates.date + pd.tseries.offsets.BQuarterEnd()]
    
    # Non-farm business labor productivity index
    def pull_data_productivity(self):
        prod = pdr.DataReader("OPHNFB", "fred", start=self.date_start_prod, end=self.date_end_prod)
        prod_index_name = prod.index.name
        prod.index = self.convert_fred_index_to_qe(prod.index)
        prod.index.name = prod_index_name
        prod = prod.dropna()
        
        return prod

    # Real GDP
    def pull_data_gdp(self):
        gdp = pdr.DataReader("GDPC1", "fred", start=self.date_start_gdp, end=self.horizon_end)
        gdp_index_name = gdp.index.name
        gdp.index = self.convert_fred_index_to_qe(gdp.index)
        gdp.index.name = gdp_index_name
        gdp = gdp.dropna()
        
        return gdp

    # Asset
    def pull_asset(self, ticker):
        asset_ser = yf.Ticker(ticker).history(start=self.horizon_start, end=self.date_end_asset)["Close"]

        asset_ser_name = asset_ser.index.name
        asset_ser.index = asset_ser.index.date
        asset_ser.index.name = asset_ser_name
        
        return asset_ser

    def get_holidays(self):
        cal_us = USFederalHolidayCalendar()
        holidays = cal_us.holidays(start=self.horizon_start, end=self.date_end_asset) # holiday date range for the window considered for the country linked to the asset

        return holidays

# %%
class Model(Modifications):
    def __init__(self, model_type, prod, gdp, assets, asset_names, holidays):
        Modifications.__init__(self)
        self.model_type = model_type
        self.model = self.load_model(self.model_type)
        self.prod = prod
        self.gdp = gdp
        self.assets = assets
        self.asset_names = asset_names
        self.holidays = holidays

        self.latest_quarters_dict = {}
        self.output_forecasts_dict = {}
        self.latest_quarters_gdp_dict = {}
        self.outputs_realised_dict = {}

    def load_model(self, model_type):
        model = yaml_import(f"yamlDSGE/{model_type}.yaml")

        return model

    def generate_signals(self, data_length_years, window_gdp_start, window_gdp_end, leverage, double_down, show_irf=False):
        assert len(self.prod) == len(self.gdp)

        data_length_quarters = self.convert_years_to_quarters(data_length_years)
        data_length_months = self.convert_years_to_months(data_length_years)

        # Check the window and preceding data are in bounds of overall productivity and GDP data
        earliest_datapoint_gdp = self.get_shifted_date(window_gdp_start, data_length_months)
        assert earliest_datapoint_gdp >= self.gdp.index[0], f"Outside bounds: {earliest_datapoint_gdp} !>= {self.gdp.index[0]}"

        earliest_datapoint_prod = self.get_shifted_date(earliest_datapoint_gdp, self.months_in_quarter)
        assert earliest_datapoint_prod >= self.prod.index[0], f"Outside bounds: {earliest_datapoint_prod} !>= {self.prod.index[0]}"

        assert window_gdp_end <= self.gdp.index[-1], f"Outside bounds: {window_gdp_end} !<= {self.gdp.index[-1]}"
        
        latest_datapoint_prod = self.get_shifted_date(window_gdp_end, self.months_in_quarter)
        assert latest_datapoint_prod <= self.prod.index[-1], f"Outside bounds: {latest_datapoint_prod} !<= {self.prod.index[-1]}"

        # Generate output forecasts
        prod_index_name = self.prod.index.name
        window_prod_start = self.get_shifted_date(window_gdp_start, self.months_in_quarter)
        window_prod_end = self.get_shifted_date(window_gdp_end, self.months_in_quarter)
        window_prod = self.prod[(self.prod.index >= window_prod_start) & (self.prod.index <= window_prod_end)]
        print("\nwindow_prod:\n")
        print(window_prod)
        
        latest_quarters = []
        output_forecasts = []
        for q in window_prod.index:
            q_key = str(q) + "_" + str(data_length_years) + "y"
            if q_key in self.latest_quarters_dict.keys():
                latest_quarters.append(self.latest_quarters_dict[q_key])
                output_forecasts.append(self.output_forecasts_dict[q_key])
                print(f"Reading IRF forecast as of {q} with {data_length_years} years of calibration")
            else:
                prod_data = self.prod[(self.prod.index >= self.get_shifted_date(q, data_length_months)) & (self.prod.index <= q)]
                assert len(prod_data.index) == data_length_quarters + 1
                
                prod_cycle, prod_trend = hpfilter(np.log(prod_data), lamb=1600)
                # prod_cycle.plot()
                
                a_hat = prod_cycle
                a = a_hat
                a_lag = a.shift()
                
                y = a.iloc[1:]
                X = a_lag.iloc[1:].values
                
                ar1 = OLS(y.values, X).fit()
                
                rho_hat = ar1.params[0]
                print(f"Estimated rho: {rho_hat:.3f}")
            
                eps_hat = pd.Series(
                    ar1.resid,
                    index=y.index,
                    name="tfp_shock"
                )
                # eps_hat.plot()
                
                latest_quarter = eps_hat.index[-1]
                latest_shock = eps_hat.iloc[-1]
                
                print(f"Estimated TFP shock for {latest_quarter}: {latest_shock:.4f}")
            
                # Set the estimated TFP persistence coefficient as a calibrated parameter in the model
                self.model.set_calibration(rho=rho_hat)
                # print(model.calibration.flat)
            
                #dr = time_iteration(model)
                dr = perturb(self.model, order=1)
                
                irf = response(self.model, dr, 'e_z', T=10, impulse=float(latest_shock))

                if show_irf == True:
                    plt.figure(figsize=(8,4))
                    plt.subplot(221)
                    plt.plot(irf.sel(V='z'))
                    plt.title('Productivity')
                    plt.grid()
                    plt.subplot(222)
                    plt.plot(irf.sel(V='y'))
                    plt.title('Output')
                    plt.grid()
                    plt.subplot(223)
                    plt.plot(irf.sel(V='i'))
                    plt.title('Investment')
                    plt.grid()
                    plt.subplot(224)
                    plt.plot(irf.sel(V='c'))
                    plt.title('Consumption')
                    plt.grid()
                    plt.tight_layout()
                    plt.show()
                
                irf_output = np.array(irf.sel(V='y'))
                
                irf_output = [(x - 1) for x in irf_output]
                output_forecast = irf_output[2]
                print(f"Next period IRF forecast as of {latest_quarter}: {output_forecast:.5f}")
                
                self.latest_quarters_dict[q_key] = latest_quarter
                latest_quarters.append(latest_quarter)
                self.output_forecasts_dict[q_key] = output_forecast
                output_forecasts.append(output_forecast)
        
        output_forecasts_ser = pd.Series(output_forecasts, index=latest_quarters) # Next period forecasts, e.g. 2025Q2 is forecast of 2025Q3
        output_forecasts_ser.name = "output_forecast"
        output_forecasts_ser.index.name = prod_index_name
        output_forecasts_df = output_forecasts_ser.to_frame()
        # output_forecasts_df

        # Obtain realised output
        gdp_index_name = self.gdp.index.name
        window_gdp = self.gdp[(self.gdp.index >= window_gdp_start) & (self.gdp.index <= window_gdp_end)]
        print("\window_gdp:\n")
        print(window_gdp)
        
        latest_quarters_gdp = []
        outputs_realised = []
        for q in window_gdp.index:
            q_key = str(q) + "_" + str(data_length_years) + "y"
            if q_key in self.latest_quarters_gdp_dict.keys():
                latest_quarters_gdp.append(self.latest_quarters_gdp_dict[q_key])
                outputs_realised.append(self.outputs_realised_dict[q_key])
                print(f"Reading realised value as of {q} with {data_length_years} years of calibration")
            else:
                gdp_data = self.gdp[(self.gdp.index >= self.get_shifted_date(q, data_length_months)) & (self.gdp.index <= q)]
                assert len(gdp_data.index) == data_length_quarters + 1
            
                gdp_cycle, gdp_trend = hpfilter(np.log(gdp_data), lamb=1600)
                output_gap = gdp_cycle
                latest_quarter_gdp = output_gap.last_valid_index()
                output_realised = output_gap.iloc[-1]
                print(f"Current period realised value as of {latest_quarter_gdp}: {output_realised:.5f}")
                
                self.latest_quarters_gdp_dict[q_key] = latest_quarter_gdp
                latest_quarters_gdp.append(latest_quarter_gdp)
                self.outputs_realised_dict[q_key] = output_realised
                outputs_realised.append(output_realised)
        
        outputs_realised_ser = pd.Series(outputs_realised, index=latest_quarters_gdp) # Realised GDP growth after HP filter, e.g. 2025Q3 reflects GDP growth in 2025Q3
        outputs_realised_ser.name = "output_realised"
        outputs_realised_ser.index.name = gdp_index_name
        outputs_realised_df = outputs_realised_ser.to_frame()
        # outputs_realised_df

        # Prepare signals
        signals_init = outputs_realised_df.join(output_forecasts_df, how="outer")
        output_forecasts_mod_df = signals_init.shift()[["output_forecast"]].dropna()
        signals = outputs_realised_df.join(output_forecasts_mod_df)
        
        def determine_pos(row, direction, leverage):
            if row["output_forecast"] > row["output_realised"]:
                pos = 1
            elif row["output_forecast"] < row["output_realised"]:
                pos = -1
            else:
                pos = 0
        
            if direction == "mr":
                pos *= -1
            
            return pos * leverage
        
        signals["pos_mom"] = signals.apply(determine_pos, axis=1, direction="mom", leverage=leverage)
        signals["pos_mr"] = signals.apply(determine_pos, axis=1, direction="mr", leverage=leverage)
        
        if double_down == True:
            signals_lagged = signals[["pos_mom", "pos_mr"]].shift().fillna(0)
            signals_lagged = signals_lagged.rename(columns={"pos_mom": "pos_mom_prev", "pos_mr": "pos_mr_prev"})
            signals = signals.join(signals_lagged)
            
            signals["double_down_scalar_mom"] = signals.apply(lambda row: 2 if row["pos_mom"] == row["pos_mom_prev"] else 1, axis=1)
            signals["double_down_scalar_mr"] = signals.apply(lambda row: 2 if row["pos_mr"] == row["pos_mr_prev"] else 1, axis=1)
        else:
            signals["double_down_scalar_mom"] = 1
            signals["double_down_scalar_mr"] = 1

        signals["pos_final_mom"] = signals["pos_mom"] * signals["double_down_scalar_mom"]
        signals["pos_final_mr"] = signals["pos_mr"] * signals["double_down_scalar_mr"]
        
        return signals

    def summarise_results(self, pos, pnl, strategy_type, asset_name):
        fig_pos, ax_pos = plt.subplots(figsize=(12, 6))
        pos.plot(ax=ax_pos, grid=True)
        plt.close(fig_pos)
        
        fig_pnl_cumsum, ax_pnl_cumsum = plt.subplots(figsize=(12, 6))
        pnl.cumsum().plot(ax=ax_pnl_cumsum, grid=True)
        plt.close(fig_pnl_cumsum)

        pnl_sum = pnl.sum()
        pnl_mean = pnl.mean()
        pnl_std = pnl.std()
        sr_daily = pnl_mean / pnl_std
        sr_annual = sr_daily * np.sqrt(252)

        results = {
            "fig_pos_" + strategy_type + "_" + asset_name: fig_pos,
            "fig_pnl_cumsum_" + strategy_type + "_" + asset_name: fig_pnl_cumsum,
            "pnl_sum_" + strategy_type + "_" + asset_name: pnl_sum,
            "pnl_mean_" + strategy_type + "_" + asset_name: pnl_mean,
            "pnl_std_" + strategy_type + "_" + asset_name: pnl_std,
            "sr_daily_" + strategy_type + "_" + asset_name: sr_daily,
            "sr_annual_" + strategy_type + "_" + asset_name: sr_annual
        }
        
        return results
    
    def run_strategy(self, signals, signal_lag, window_gdp_start, window_gdp_end, show_pos=False):
        # Delay signals by a particular number of business days to account for lag in GDP and productivity data availability
        signals_actual = signals[["output_realised", "output_forecast", "pos_final_mom", "pos_final_mr"]]
        signals_actual.index += pd.offsets.CustomBusinessDay(n=signal_lag, holidays=self.holidays)
        
        date_end_asset = self.get_shifted_date(window_gdp_end, self.months_in_quarter, "forwards")
        results = {"signals_actual": signals_actual}
        for i, asset in enumerate(self.assets):
            asset_ser = asset[(asset.index >= window_gdp_start) & (asset.index <= date_end_asset)]
            asset_ret_ser = asset_ser.pct_change()
            asset_ret_ser.name = "Return"

            asset_ret_df = asset_ret_ser.to_frame()
            asset_ret_df = asset_ret_df.join(signals_actual[["pos_final_mom", "pos_final_mr"]]).ffill().fillna(0)
            if show_pos:
                asset_ret_df.plot(figsize=(12, 6), grid=True)

            asset_ret_lagged_df = asset_ret_df[["pos_final_mom", "pos_final_mr"]].shift()
            pnl = asset_ret_df[["Return"]].join(asset_ret_lagged_df).fillna(0)

            cost_per_trade = 0.0001 # 1 bp
            cost = abs(pnl[["pos_final_mom", "pos_final_mr"]].diff().fillna(0).rename(columns={"pos_final_mom": "cost_mom", "pos_final_mr": "cost_mr"})) * 0.5 * cost_per_trade
            pnl_full = pnl.join(cost)
            
            pnl_full["pnlg_mom"] = pnl_full["Return"] * pnl_full["pos_final_mom"]
            pnl_full["pnln_mom"] = pnl_full["pnlg_mom"] - pnl_full["cost_mom"]
            pnl_full["pnlg_mr"] = pnl_full["Return"] * pnl_full["pos_final_mr"]
            pnl_full["pnln_mr"] = pnl_full["pnlg_mr"] - pnl_full["cost_mr"]

            results_momg = self.summarise_results(asset_ret_df["pos_final_mom"], pnl_full["pnlg_mom"], "momg", self.asset_names[i])
            results_momn = self.summarise_results(asset_ret_df["pos_final_mom"], pnl_full["pnln_mom"], "momn", self.asset_names[i])
            results_mrg = self.summarise_results(asset_ret_df["pos_final_mr"], pnl_full["pnlg_mr"], "mrg", self.asset_names[i])
            results_mrn = self.summarise_results(asset_ret_df["pos_final_mr"], pnl_full["pnln_mr"], "mrn", self.asset_names[i])
            results = results | results_momg | results_momn | results_mrg | results_mrn

        return results

# %%
class BuyAndHold(Modifications):
    def __init__(self, assets, asset_names):
        Modifications.__init__(self)
        self.assets = assets
        self.asset_names = asset_names

    def run_strategy(self, window_start, window_end):
        date_end_asset = self.get_shifted_date(window_end, self.months_in_quarter, "forwards")
        results = {"signals_actual": 1}
        for i, asset in enumerate(self.assets):
            asset_ser = asset[(asset.index >= window_start) & (asset.index <= date_end_asset)]
    
            asset_ret_ser = asset_ser.pct_change().fillna(0)
            asset_ret_ser.name = "Return"
            pnl = asset_ret_ser
            
            fig_pnl_cumsum, ax_pnl_cumsum = plt.subplots(figsize=(12, 6))
            pnl.cumsum().plot(ax=ax_pnl_cumsum, grid=True)
            plt.close(fig_pnl_cumsum)
    
            pnl_sum = pnl.sum()
            pnl_mean = pnl.mean()
            pnl_std = pnl.std()
            sr_daily = pnl_mean / pnl_std
            sr_annual = sr_daily * np.sqrt(252)
            
            results_bh = {
                "fig_pnl_cumsum_" + self.asset_names[i]: fig_pnl_cumsum,
                "pnl_sum_" + self.asset_names[i]: pnl_sum,
                "pnl_mean_" + self.asset_names[i]: pnl_mean,
                "pnl_std_" + self.asset_names[i]: pnl_std,
                "sr_daily_" + self.asset_names[i]: sr_daily,
                "sr_annual_" + self.asset_names[i]: sr_annual
            }

            results = results | results_bh

        return results

# %%
data_10y_19991231_20250930 = Data(10, "1999-12-31", "2025-09-30")

# %%
# rbc = Model(
#     "rbc", 
#     data_20y_19991231_20250930.prod, 
#     data_20y_19991231_20250930.gdp, 
#     data_20y_19991231_20250930.asset,
#     data_20y_19991231_20250930.holidays
# )

# %%
rbc = Model(
    "rbc", 
    data_10y_19991231_20250930.prod, 
    data_10y_19991231_20250930.gdp, 
    [data_10y_19991231_20250930.asset_sp500],
    ["SP"],
    data_10y_19991231_20250930.holidays
)

# signals = rbc.generate_signals(10, dt.date(1999, 12, 31), dt.date(2025, 9, 30), 1, False, show_irf=True)
signals = rbc.generate_signals(10, dt.date(1999, 12, 31), dt.date(2025, 9, 30), 1, False)
# Out:
# window_prod:
#
#              OPHNFB
# DATE
# 1999-09-30   70.469
# 1999-12-31   71.516
# 2000-03-31   71.222
# 2000-06-30   72.657
# 2000-09-29   72.587
# ...             ...
# 2024-06-28  114.990
# 2024-09-30  116.035
# 2024-12-31  116.445
# 2025-03-31  116.187
# 2025-06-30  117.385
#
# [104 rows x 1 columns]
# Estimated rho: 0.814
# Estimated TFP shock for 1999-09-30: 0.0044
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D47AD0>
# 10 [0.00444541]
# Next period IRF forecast as of 1999-09-30: 0.00071
# Estimated rho: 0.824
# Estimated TFP shock for 1999-12-31: 0.0094
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0F9A150>
# 10 [0.00938512]
# Next period IRF forecast as of 1999-12-31: 0.00694
# Estimated rho: 0.789
# Estimated TFP shock for 2000-03-31: -0.0079
# <dolo.numeric.distribution.UNormal object at 0x0000018FC194A610>
# 10 [-0.0078606]
# Next period IRF forecast as of 2000-03-31: -0.01502
# Estimated rho: 0.785
# Estimated TFP shock for 2000-06-30: 0.0128
# <dolo.numeric.distribution.UNormal object at 0x0000018FBACD3810>
# 10 [0.01281424]
# Next period IRF forecast as of 2000-06-30: 0.01173
# Estimated rho: 0.761
# Estimated TFP shock for 2000-09-29: -0.0054
# <dolo.numeric.distribution.UNormal object at 0x0000018FBEEDFC90>
# 10 [-0.00542126]
# Next period IRF forecast as of 2000-09-29: -0.01200
# Estimated rho: 0.753
# Estimated TFP shock for 2000-12-29: 0.0035
# <dolo.numeric.distribution.UNormal object at 0x0000018FB97A2810>
# 10 [0.00354642]
# Next period IRF forecast as of 2000-12-29: -0.00028
# Estimated rho: 0.682
# Estimated TFP shock for 2001-03-30: -0.0109
# <dolo.numeric.distribution.UNormal object at 0x0000018FC17634D0>
# 10 [-0.010934]
# Next period IRF forecast as of 2001-03-30: -0.01951
# Estimated rho: 0.658
# Estimated TFP shock for 2001-06-29: 0.0071
# <dolo.numeric.distribution.UNormal object at 0x0000018FC19C8750>
# 10 [0.00707292]
# Next period IRF forecast as of 2001-06-29: 0.00465
# Estimated rho: 0.622
# Estimated TFP shock for 2001-09-28: -0.0011
# <dolo.numeric.distribution.UNormal object at 0x0000018FB8FE6410>
# 10 [-0.00112572]
# Next period IRF forecast as of 2001-09-28: -0.00647
# Estimated rho: 0.553
# Estimated TFP shock for 2001-12-31: 0.0045
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D0B050>
# 10 [0.00450491]
# Next period IRF forecast as of 2001-12-31: 0.00127
# Estimated rho: 0.571
# Estimated TFP shock for 2002-03-29: 0.0130
# <dolo.numeric.distribution.UNormal object at 0x0000018FC194D5D0>
# 10 [0.0129948]
# Next period IRF forecast as of 2002-03-29: 0.01303
# Estimated rho: 0.549
# Estimated TFP shock for 2002-06-28: -0.0012
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F18550>
# 10 [-0.00121909]
# Next period IRF forecast as of 2002-06-28: -0.00662
# Estimated rho: 0.520
# Estimated TFP shock for 2002-09-30: 0.0014
# <dolo.numeric.distribution.UNormal object at 0x0000018FC15F1AD0>
# 10 [0.00144563]
# Next period IRF forecast as of 2002-09-30: -0.00294
# Estimated rho: 0.436
# Estimated TFP shock for 2002-12-31: -0.0068
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F20210>
# 10 [-0.00682598]
# Next period IRF forecast as of 2002-12-31: -0.01441
# Estimated rho: 0.465
# Estimated TFP shock for 2003-03-31: -0.0006
# <dolo.numeric.distribution.UNormal object at 0x0000018FC47DFE50>
# 10 [-0.00062248]
# Next period IRF forecast as of 2003-03-31: -0.00581
# Estimated rho: 0.504
# Estimated TFP shock for 2003-06-30: 0.0034
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAC8B390>
# 10 [0.00339713]
# Next period IRF forecast as of 2003-06-30: -0.00023
# Estimated rho: 0.478
# Estimated TFP shock for 2003-09-30: 0.0128
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F55F50>
# 10 [0.01275532]
# Next period IRF forecast as of 2003-09-30: 0.01290
# Estimated rho: 0.480
# Estimated TFP shock for 2003-12-31: 0.0058
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAC8B390>
# 10 [0.00580666]
# Next period IRF forecast as of 2003-12-31: 0.00314
# Estimated rho: 0.411
# Estimated TFP shock for 2004-03-31: -0.0054
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F06410>
# 10 [-0.00538973]
# Next period IRF forecast as of 2004-03-31: -0.01244
# Estimated rho: 0.375
# Estimated TFP shock for 2004-06-30: 0.0009
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F3E1D0>
# 10 [0.00091706]
# Next period IRF forecast as of 2004-06-30: -0.00366
# Estimated rho: 0.423
# Estimated TFP shock for 2004-09-30: -0.0034
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F66250>
# 10 [-0.00340179]
# Next period IRF forecast as of 2004-09-30: -0.00968
# Estimated rho: 0.406
# Estimated TFP shock for 2004-12-31: -0.0050
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F2F3D0>
# 10 [-0.00504484]
# Next period IRF forecast as of 2004-12-31: -0.01197
# Estimated rho: 0.400
# Estimated TFP shock for 2005-03-31: -0.0009
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2EC2150>
# 10 [-0.00085925]
# Next period IRF forecast as of 2005-03-31: -0.00614
# Estimated rho: 0.386
# Estimated TFP shock for 2005-06-30: -0.0095
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F3E410>
# 10 [-0.00948153]
# Next period IRF forecast as of 2005-06-30: -0.01813
# Estimated rho: 0.428
# Estimated TFP shock for 2005-09-30: -0.0055
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D50D50>
# 10 [-0.00553164]
# Next period IRF forecast as of 2005-09-30: -0.01263
# Estimated rho: 0.466
# Estimated TFP shock for 2005-12-30: -0.0106
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAB141D0>
# 10 [-0.01056837]
# Next period IRF forecast as of 2005-12-30: -0.01953
# Estimated rho: 0.490
# Estimated TFP shock for 2006-03-31: -0.0059
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2EC2350>
# 10 [-0.00589173]
# Next period IRF forecast as of 2006-03-31: -0.01308
# Estimated rho: 0.498
# Estimated TFP shock for 2006-06-30: -0.0117
# <dolo.numeric.distribution.UNormal object at 0x0000018FC18E9D10>
# 10 [-0.01173649]
# Next period IRF forecast as of 2006-06-30: -0.02108
# Estimated rho: 0.540
# Estimated TFP shock for 2006-09-29: -0.0133
# <dolo.numeric.distribution.UNormal object at 0x0000018FC05E6810>
# 10 [-0.0133229]
# Next period IRF forecast as of 2006-09-29: -0.02315
# Estimated rho: 0.572
# Estimated TFP shock for 2006-12-29: -0.0062
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAA4B610>
# 10 [-0.00615582]
# Next period IRF forecast as of 2006-12-29: -0.01335
# Estimated rho: 0.611
# Estimated TFP shock for 2007-03-30: -0.0065
# <dolo.numeric.distribution.UNormal object at 0x0000018FC16C4150>
# 10 [-0.00654956]
# Next period IRF forecast as of 2007-03-30: -0.01383
# Estimated rho: 0.630
# Estimated TFP shock for 2007-06-29: -0.0061
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2BFAF50>
# 10 [-0.00613351]
# Next period IRF forecast as of 2007-06-29: -0.01324
# Estimated rho: 0.613
# Estimated TFP shock for 2007-09-28: -0.0005
# <dolo.numeric.distribution.UNormal object at 0x0000018FB9792850>
# 10 [-0.00049175]
# Next period IRF forecast as of 2007-09-28: -0.00561
# Estimated rho: 0.604
# Estimated TFP shock for 2007-12-31: 0.0005
# <dolo.numeric.distribution.UNormal object at 0x0000018FBACB40D0>
# 10 [0.00048182]
# Next period IRF forecast as of 2007-12-31: -0.00428
# Estimated rho: 0.585
# Estimated TFP shock for 2008-03-31: -0.0114
# <dolo.numeric.distribution.UNormal object at 0x0000018FB977A290>
# 10 [-0.01140015]
# Next period IRF forecast as of 2008-03-31: -0.02044
# Estimated rho: 0.558
# Estimated TFP shock for 2008-06-30: 0.0025
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1A7FF50>
# 10 [0.00246313]
# Next period IRF forecast as of 2008-06-30: -0.00155
# Estimated rho: 0.560
# Estimated TFP shock for 2008-09-30: -0.0029
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0F755D0>
# 10 [-0.0029306]
# Next period IRF forecast as of 2008-09-30: -0.00896
# Estimated rho: 0.546
# Estimated TFP shock for 2008-12-31: -0.0101
# <dolo.numeric.distribution.UNormal object at 0x0000018FBACD7D90>
# 10 [-0.01012191]
# Next period IRF forecast as of 2008-12-31: -0.01879
# Estimated rho: 0.533
# Estimated TFP shock for 2009-03-31: 0.0026
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2AB7110>
# 10 [0.00261756]
# Next period IRF forecast as of 2009-03-31: -0.00133
# Estimated rho: 0.528
# Estimated TFP shock for 2009-06-30: 0.0158
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1A73290>
# 10 [0.01582675]
# Next period IRF forecast as of 2009-06-30: 0.01711
# Estimated rho: 0.622
# Estimated TFP shock for 2009-09-30: 0.0143
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF4D6950>
# 10 [0.01429872]
# Next period IRF forecast as of 2009-09-30: 0.01467
# Estimated rho: 0.708
# Estimated TFP shock for 2009-12-31: 0.0124
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAA540D0>
# 10 [0.01236667]
# Next period IRF forecast as of 2009-12-31: 0.01165
# Estimated rho: 0.724
# Estimated TFP shock for 2010-03-31: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F91C50>
# 10 [0.00067527]
# Next period IRF forecast as of 2010-03-31: -0.00405
# Estimated rho: 0.746
# Estimated TFP shock for 2010-06-30: 0.0005
# <dolo.numeric.distribution.UNormal object at 0x0000018FC4836F50>
# 10 [0.00049252]
# Next period IRF forecast as of 2010-06-30: -0.00429
# Estimated rho: 0.754
# Estimated TFP shock for 2010-09-30: 0.0022
# <dolo.numeric.distribution.UNormal object at 0x0000018FBEEBD8D0>
# 10 [0.00218538]
# Next period IRF forecast as of 2010-09-30: -0.00208
# Estimated rho: 0.753
# Estimated TFP shock for 2010-12-31: -0.0014
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF594A10>
# 10 [-0.00138319]
# Next period IRF forecast as of 2010-12-31: -0.00675
# Estimated rho: 0.730
# Estimated TFP shock for 2011-03-31: -0.0120
# <dolo.numeric.distribution.UNormal object at 0x0000018FC081D7D0>
# 10 [-0.01197134]
# Next period IRF forecast as of 2011-03-31: -0.02066
# Estimated rho: 0.761
# Estimated TFP shock for 2011-06-30: -0.0065
# <dolo.numeric.distribution.UNormal object at 0x0000018FBA870050>
# 10 [-0.00652277]
# Next period IRF forecast as of 2011-06-30: -0.01343
# Estimated rho: 0.762
# Estimated TFP shock for 2011-09-30: -0.0091
# <dolo.numeric.distribution.UNormal object at 0x0000018FB96FBD50>
# 10 [-0.00906602]
# Next period IRF forecast as of 2011-09-30: -0.01672
# Estimated rho: 0.769
# Estimated TFP shock for 2011-12-30: -0.0031
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0937BD0>
# 10 [-0.0031019]
# Next period IRF forecast as of 2011-12-30: -0.00897
# Estimated rho: 0.809
# Estimated TFP shock for 2012-03-30: -0.0018
# <dolo.numeric.distribution.UNormal object at 0x0000018FC076E1D0>
# 10 [-0.00177439]
# Next period IRF forecast as of 2012-03-30: -0.00720
# Estimated rho: 0.805
# Estimated TFP shock for 2012-06-29: -0.0011
# <dolo.numeric.distribution.UNormal object at 0x0000018FC05AEC50>
# 10 [-0.00107785]
# Next period IRF forecast as of 2012-06-29: -0.00632
# Estimated rho: 0.809
# Estimated TFP shock for 2012-09-28: -0.0082
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF53A690>
# 10 [-0.0082274]
# Next period IRF forecast as of 2012-09-28: -0.01537
# Estimated rho: 0.794
# Estimated TFP shock for 2012-12-31: -0.0094
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0936690>
# 10 [-0.00943409]
# Next period IRF forecast as of 2012-12-31: -0.01699
# Estimated rho: 0.773
# Estimated TFP shock for 2013-03-29: -0.0018
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2AED9D0>
# 10 [-0.00176236]
# Next period IRF forecast as of 2013-03-29: -0.00723
# Estimated rho: 0.779
# Estimated TFP shock for 2013-06-28: -0.0077
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF551FD0>
# 10 [-0.00765984]
# Next period IRF forecast as of 2013-06-28: -0.01482
# Estimated rho: 0.817
# Estimated TFP shock for 2013-09-30: 0.0018
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF4EEE10>
# 10 [0.00180016]
# Next period IRF forecast as of 2013-09-30: -0.00266
# Estimated rho: 0.807
# Estimated TFP shock for 2013-12-31: 0.0051
# <dolo.numeric.distribution.UNormal object at 0x0000018FC143ABD0>
# 10 [0.005093]
# Next period IRF forecast as of 2013-12-31: 0.00157
# Estimated rho: 0.807
# Estimated TFP shock for 2014-03-31: -0.0108
# <dolo.numeric.distribution.UNormal object at 0x0000018FB9771350>
# 10 [-0.01081657]
# Next period IRF forecast as of 2014-03-31: -0.01864
# Estimated rho: 0.803
# Estimated TFP shock for 2014-06-30: 0.0022
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0BA2990>
# 10 [0.00219382]
# Next period IRF forecast as of 2014-06-30: -0.00213
# Estimated rho: 0.796
# Estimated TFP shock for 2014-09-30: 0.0050
# <dolo.numeric.distribution.UNormal object at 0x0000018FBACD2950>
# 10 [0.00496394]
# Next period IRF forecast as of 2014-09-30: 0.00145
# Estimated rho: 0.791
# Estimated TFP shock for 2014-12-31: -0.0054
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1873D50>
# 10 [-0.00541975]
# Next period IRF forecast as of 2014-12-31: -0.01189
# Estimated rho: 0.783
# Estimated TFP shock for 2015-03-31: 0.0026
# <dolo.numeric.distribution.UNormal object at 0x0000018FB73A8E10>
# 10 [0.00256506]
# Next period IRF forecast as of 2015-03-31: -0.00162
# Estimated rho: 0.787
# Estimated TFP shock for 2015-06-30: 0.0023
# <dolo.numeric.distribution.UNormal object at 0x0000018FC18C34D0>
# 10 [0.00233831]
# Next period IRF forecast as of 2015-06-30: -0.00192
# Estimated rho: 0.778
# Estimated TFP shock for 2015-09-30: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0607190>
# 10 [0.00066731]
# Next period IRF forecast as of 2015-09-30: -0.00408
# Estimated rho: 0.771
# Estimated TFP shock for 2015-12-31: -0.0077
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1843E90>
# 10 [-0.00774871]
# Next period IRF forecast as of 2015-12-31: -0.01497
# Estimated rho: 0.754
# Estimated TFP shock for 2016-03-31: 0.0009
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAC1F0D0>
# 10 [0.00090429]
# Next period IRF forecast as of 2016-03-31: -0.00376
# Estimated rho: 0.755
# Estimated TFP shock for 2016-06-30: -0.0019
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0931A10>
# 10 [-0.00191077]
# Next period IRF forecast as of 2016-06-30: -0.00744
# Estimated rho: 0.761
# Estimated TFP shock for 2016-09-30: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x0000018FC19CBA10>
# 10 [0.00068223]
# Next period IRF forecast as of 2016-09-30: -0.00405
# Estimated rho: 0.759
# Estimated TFP shock for 2016-12-30: 0.0041
# <dolo.numeric.distribution.UNormal object at 0x0000018FC16BE350>
# 10 [0.00414918]
# Next period IRF forecast as of 2016-12-30: 0.00049
# Estimated rho: 0.760
# Estimated TFP shock for 2017-03-31: 0.0000
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D08150>
# 10 [7.02367318e-06]
# Next period IRF forecast as of 2017-03-31: -0.00493
# Estimated rho: 0.758
# Estimated TFP shock for 2017-06-30: -0.0012
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2ADA810>
# 10 [-0.00120584]
# Next period IRF forecast as of 2017-06-30: -0.00652
# Estimated rho: 0.764
# Estimated TFP shock for 2017-09-29: 0.0056
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D68D90>
# 10 [0.00557768]
# Next period IRF forecast as of 2017-09-29: 0.00236
# Estimated rho: 0.774
# Estimated TFP shock for 2017-12-29: 0.0055
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1644110>
# 10 [0.00550637]
# Next period IRF forecast as of 2017-12-29: 0.00223
# Estimated rho: 0.767
# Estimated TFP shock for 2018-03-30: 0.0020
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F3DF10>
# 10 [0.0020184]
# Next period IRF forecast as of 2018-03-30: -0.00231
# Estimated rho: 0.775
# Estimated TFP shock for 2018-06-29: -0.0013
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2D48350>
# 10 [-0.0013212]
# Next period IRF forecast as of 2018-06-29: -0.00666
# Estimated rho: 0.749
# Estimated TFP shock for 2018-09-28: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF533F90>
# 10 [0.00071265]
# Next period IRF forecast as of 2018-09-28: -0.00401
# Estimated rho: 0.637
# Estimated TFP shock for 2018-12-31: -0.0036
# <dolo.numeric.distribution.UNormal object at 0x0000018FBEF793D0>
# 10 [-0.00355842]
# Next period IRF forecast as of 2018-12-31: -0.00976
# Estimated rho: 0.475
# Estimated TFP shock for 2019-03-29: 0.0041
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAD56750>
# 10 [0.00412962]
# Next period IRF forecast as of 2019-03-29: 0.00081
# Estimated rho: 0.391
# Estimated TFP shock for 2019-06-28: 0.0041
# <dolo.numeric.distribution.UNormal object at 0x0000018FC06FC610>
# 10 [0.00408667]
# Next period IRF forecast as of 2019-06-28: 0.00079
# Estimated rho: 0.334
# Estimated TFP shock for 2019-09-30: 0.0094
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0601DD0>
# 10 [0.0093522]
# Next period IRF forecast as of 2019-09-30: 0.00827
# Estimated rho: 0.470
# Estimated TFP shock for 2019-12-31: 0.0093
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1A46E50>
# 10 [0.0093386]
# Next period IRF forecast as of 2019-12-31: 0.00810
# Estimated rho: 0.435
# Estimated TFP shock for 2020-03-31: -0.0013
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF532410>
# 10 [-0.00125896]
# Next period IRF forecast as of 2020-03-31: -0.00670
# Estimated rho: 0.235
# Estimated TFP shock for 2020-06-30: 0.0390
# <dolo.numeric.distribution.UNormal object at 0x0000018FB9714450>
# 10 [0.03902133]
# Next period IRF forecast as of 2020-06-30: 0.05153
# Estimated rho: 0.711
# Estimated TFP shock for 2020-09-30: 0.0179
# <dolo.numeric.distribution.UNormal object at 0x0000018FC48163D0>
# 10 [0.01793553]
# Next period IRF forecast as of 2020-09-30: 0.01919
# Estimated rho: 0.620
# Estimated TFP shock for 2020-12-31: -0.0016
# <dolo.numeric.distribution.UNormal object at 0x0000018FB97B4310>
# 10 [-0.00157987]
# Next period IRF forecast as of 2020-12-31: -0.00709
# Estimated rho: 0.639
# Estimated TFP shock for 2021-03-31: 0.0059
# <dolo.numeric.distribution.UNormal object at 0x0000018FC19D70D0>
# 10 [0.00591972]
# Next period IRF forecast as of 2021-03-31: 0.00311
# Estimated rho: 0.623
# Estimated TFP shock for 2021-06-30: 0.0001
# <dolo.numeric.distribution.UNormal object at 0x0000018FC15F3290>
# 10 [0.00011955]
# Next period IRF forecast as of 2021-06-30: -0.00478
# Estimated rho: 0.608
# Estimated TFP shock for 2021-09-30: -0.0095
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1A0EA10>
# 10 [-0.00947975]
# Next period IRF forecast as of 2021-09-30: -0.01779
# Estimated rho: 0.617
# Estimated TFP shock for 2021-12-31: -0.0024
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAA89250>
# 10 [-0.00244854]
# Next period IRF forecast as of 2021-12-31: -0.00827
# Estimated rho: 0.646
# Estimated TFP shock for 2022-03-31: -0.0192
# <dolo.numeric.distribution.UNormal object at 0x0000018FC17630D0>
# 10 [-0.01915225]
# Next period IRF forecast as of 2022-03-31: -0.03056
# Estimated rho: 0.714
# Estimated TFP shock for 2022-06-30: -0.0170
# <dolo.numeric.distribution.UNormal object at 0x0000018FF0E9C710>
# 10 [-0.01701503]
# Next period IRF forecast as of 2022-06-30: -0.02733
# Estimated rho: 0.761
# Estimated TFP shock for 2022-09-30: -0.0095
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF52EA90>
# 10 [-0.00948427]
# Next period IRF forecast as of 2022-09-30: -0.01726
# Estimated rho: 0.776
# Estimated TFP shock for 2022-12-30: -0.0035
# <dolo.numeric.distribution.UNormal object at 0x0000018FC19B0410>
# 10 [-0.00353058]
# Next period IRF forecast as of 2022-12-30: -0.00951
# Estimated rho: 0.784
# Estimated TFP shock for 2023-03-31: -0.0052
# <dolo.numeric.distribution.UNormal object at 0x0000018FC167A610>
# 10 [-0.00519158]
# Next period IRF forecast as of 2023-03-31: -0.01163
# Estimated rho: 0.778
# Estimated TFP shock for 2023-06-30: 0.0027
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0744390>
# 10 [0.00274306]
# Next period IRF forecast as of 2023-06-30: -0.00138
# Estimated rho: 0.770
# Estimated TFP shock for 2023-09-29: 0.0064
# <dolo.numeric.distribution.UNormal object at 0x0000018FC1647710>
# 10 [0.00644037]
# Next period IRF forecast as of 2023-09-29: 0.00347
# Estimated rho: 0.767
# Estimated TFP shock for 2023-12-29: 0.0054
# <dolo.numeric.distribution.UNormal object at 0x0000018FBF52EA90>
# 10 [0.00540826]
# Next period IRF forecast as of 2023-12-29: 0.00213
# Estimated rho: 0.780
# Estimated TFP shock for 2024-03-29: -0.0024
# <dolo.numeric.distribution.UNormal object at 0x0000018FC2F39910>
# 10 [-0.00242325]
# Next period IRF forecast as of 2024-03-29: -0.00807
# Estimated rho: 0.780
# Estimated TFP shock for 2024-06-28: 0.0050
# <dolo.numeric.distribution.UNormal object at 0x0000018FC0850050>
# 10 [0.00501241]
# Next period IRF forecast as of 2024-06-28: 0.00156
# Estimated rho: 0.780
# Estimated TFP shock for 2024-09-30: 0.0055
# <dolo.numeric.distribution.UNormal object at 0x0000018FBAD43A50>
# 10 [0.0054702]
# Next period IRF forecast as of 2024-09-30: 0.00216
# Estimated rho: 0.787
# Estimated TFP shock for 2024-12-31: 0.0005
# <dolo.numeric.distribution.UNormal object at 0x0000018FC14ED650>
# 10 [0.00053959]
# Next period IRF forecast as of 2024-12-31: -0.00425
# Estimated rho: 0.779
# Estimated TFP shock for 2025-03-31: -0.0053
# <dolo.numeric.distribution.UNormal object at 0x0000018FBA9DCC90>
# 10 [-0.00527931]
# Next period IRF forecast as of 2025-03-31: -0.01176
# Estimated rho: 0.771
# Estimated TFP shock for 2025-06-30: 0.0054
# <dolo.numeric.distribution.UNormal object at 0x0000018FC15B7CD0>
# 10 [0.0054214]
# Next period IRF forecast as of 2025-06-30: 0.00213
# \window_gdp:
#
#                 GDPC1
# DATE
# 1999-12-31  13827.980
# 2000-03-31  13878.147
# 2000-06-30  14130.908
# 2000-09-29  14145.312
# 2000-12-29  14229.765
# ...               ...
# 2024-09-30  23478.570
# 2024-12-31  23586.542
# 2025-03-31  23548.210
# 2025-06-30  23770.976
# 2025-09-30  24026.834
# Current period realised value as of 2018-03-30: 0.00508
# Current period realised value as of 2018-06-29: 0.00343
# Current period realised value as of 2018-09-28: 0.00284
# Current period realised value as of 2018-12-31: -0.00150
# Current period realised value as of 2019-03-29: -0.00113
# Current period realised value as of 2019-06-28: 0.00083
# Current period realised value as of 2019-09-30: 0.00501
# Current period realised value as of 2019-12-31: 0.00436
# Current period realised value as of 2020-03-31: -0.01227
# Current period realised value as of 2020-06-30: -0.08028
# Current period realised value as of 2020-09-30: -0.00749
# Current period realised value as of 2020-12-31: 0.00013
# Current period realised value as of 2021-03-31: 0.00830
# Current period realised value as of 2021-06-30: 0.01704
# Current period realised value as of 2021-09-30: 0.01672
# Current period realised value as of 2021-12-31: 0.02311
# Current period realised value as of 2022-03-31: 0.01208
# Current period realised value as of 2022-06-30: 0.00629
# Current period realised value as of 2022-09-30: 0.00603
# Current period realised value as of 2022-12-30: 0.00543
# Current period realised value as of 2023-03-31: 0.00507
# Current period realised value as of 2023-06-30: 0.00392
# Current period realised value as of 2023-09-29: 0.00706
# Current period realised value as of 2023-12-29: 0.00696
# Current period realised value as of 2024-03-29: 0.00169
# Current period realised value as of 2024-06-28: 0.00277
# Current period realised value as of 2024-09-30: 0.00310
# Current period realised value as of 2024-12-31: 0.00041
# Current period realised value as of 2025-03-31: -0.00672
# Current period realised value as of 2025-06-30: -0.00343
# Current period realised value as of 2025-09-30: 0.00031

# %%
# strategy = rbc.run_strategy(signals, 10, dt.date(1999, 12, 31), dt.date(2025, 9, 30), show_pos=True)
strategy = rbc.run_strategy(signals, 10, dt.date(1999, 12, 31), dt.date(2025, 9, 30))

# %%
signals
# Out:
#             output_realised  output_forecast  pos_mom  pos_mr  \
# DATE
# 1999-12-31         0.009403         0.000712       -1       1
# 2000-03-31         0.001798         0.006943        1      -1
# 2000-06-30         0.007257        -0.015021       -1       1
# 2000-09-29        -0.002123         0.011726        1      -1
# 2000-12-29        -0.005608        -0.012001       -1       1
# ...                     ...              ...      ...     ...
# 2024-09-30         0.003100         0.001564       -1       1
# 2024-12-31         0.000410         0.002164        1      -1
# 2025-03-31        -0.006721        -0.004246        1      -1
# 2025-06-30        -0.003433        -0.011759       -1       1
# 2025-09-30         0.000310         0.002130        1      -1
#
#             double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
# DATE
# 1999-12-31                       1                      1             -1
# 2000-03-31                       1                      1              1
# 2000-06-30                       1                      1             -1
# 2000-09-29                       1                      1              1
# 2000-12-29                       1                      1             -1
# ...                            ...                    ...            ...
# 2024-09-30                       1                      1             -1
# 2024-12-31                       1                      1              1
# 2025-03-31                       1                      1              1
# 2025-06-30                       1                      1             -1
# 2025-09-30                       1                      1              1
#
#             pos_final_mr
# DATE
# 1999-12-31             1
# 2000-03-31            -1
# 2000-06-30             1
# 2000-09-29            -1
# 2000-12-29             1
# ...                  ...
# 2024-09-30             1
# 2024-12-31            -1
# 2025-03-31            -1
# 2025-06-30             1
# 2025-09-30            -1
#
# [104 rows x 8 columns]

# %%
# signals["pos_final_mr"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
# strategy
# Out:
# {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#  DATE
#  2000-01-14         0.009403         0.000712             -1             1
#  2000-04-14         0.001798         0.006943              1            -1
#  2000-07-17         0.007257        -0.015021             -1             1
#  2000-10-16        -0.002123         0.011726              1            -1
#  2001-01-16        -0.005608        -0.012001             -1             1
#  ...                     ...              ...            ...           ...
#  2024-10-15         0.003100         0.001564             -1             1
#  2025-01-15         0.000410         0.002164              1            -1
#  2025-04-14        -0.006721        -0.004246              1            -1
#  2025-07-15        -0.003433        -0.011759             -1             1
#  2025-10-15         0.000310         0.002130              1            -1
#
#  [104 rows x 4 columns],
#  'fig_pos_momg_SP': <Figure size 1200x600 with 1 Axes>,
#  'fig_pnl_cumsum_momg_SP': <Figure size 1200x600 with 1 Axes>,
#  'pnl_sum_momg_SP': -0.5084471132887742,
#  'pnl_mean_momg_SP': -7.774420692488903e-05,
#  'pnl_std_momg_SP': 0.012183251263728139,
#  'sr_daily_momg_SP': -0.006381236440255349,
#  'sr_annual_momg_SP': -0.10129898806811238,
#  'fig_pos_momn_SP': <Figure size 1200x600 with 1 Axes>,
#  'fig_pnl_cumsum_momn_SP': <Figure size 1200x600 with 1 Axes>,
#  'pnl_sum_momn_SP': -0.5103971132887741,
#  'pnl_mean_momn_SP': -7.804237206250369e-05,
#  'pnl_std_momn_SP': 0.0121831806389924,
#  'sr_daily_momn_SP': -0.006405746937111663,
#  'sr_annual_momn_SP': -0.10168808014326701,
#  'fig_pos_mrg_SP': <Figure size 1200x600 with 1 Axes>,
#  'fig_pnl_cumsum_mrg_SP': <Figure size 1200x600 with 1 Axes>,
#  'pnl_sum_mrg_SP': 0.5084471132887742,
#  'pnl_mean_mrg_SP': 7.774420692488903e-05,
#  'pnl_std_mrg_SP': 0.012183251263728139,
#  'sr_daily_mrg_SP': 0.006381236440255349,
#  'sr_annual_mrg_SP': 0.10129898806811238,
#  'fig_pos_mrn_SP': <Figure size 1200x600 with 1 Axes>,
#  'fig_pnl_cumsum_mrn_SP': <Figure size 1200x600 with 1 Axes>,
#  'pnl_sum_mrn_SP': 0.5064971132887743,
#  'pnl_mean_mrn_SP': 7.744604178727437e-05,
#  'pnl_std_mrn_SP': 0.012183324297071772,
#  'sr_daily_mrn_SP': 0.006356724970859416,
#  'sr_annual_mrn_SP': 0.10090988055436993}

# %%
# strategy.keys()
# Out:
# dict_keys(['signals_actual', 'fig_pos_momg_SP', 'fig_pnl_cumsum_momg_SP', 'pnl_sum_momg_SP', 'pnl_mean_momg_SP', 'pnl_std_momg_SP', 'sr_daily_momg_SP', 'sr_annual_momg_SP', 'fig_pos_momn_SP', 'fig_pnl_cumsum_momn_SP', 'pnl_sum_momn_SP', 'pnl_mean_momn_SP', 'pnl_std_momn_SP', 'sr_daily_momn_SP', 'sr_annual_momn_SP', 'fig_pos_mrg_SP', 'fig_pnl_cumsum_mrg_SP', 'pnl_sum_mrg_SP', 'pnl_mean_mrg_SP', 'pnl_std_mrg_SP', 'sr_daily_mrg_SP', 'sr_annual_mrg_SP', 'fig_pos_mrn_SP', 'fig_pnl_cumsum_mrn_SP', 'pnl_sum_mrn_SP', 'pnl_mean_mrn_SP', 'pnl_std_mrn_SP', 'sr_daily_mrn_SP', 'sr_annual_mrn_SP'])

# %%
# strategy["pnl_sum_momg_SP"]
# Out:
# -0.5084471132887742

# %%
# strategy["pnl_sum_momn_SP"]
# Out:
# -0.5103971132887741

# %%
# strategy["fig_pnl_cumsum_momg_SP"]

# %%
# strategy["fig_pnl_cumsum_momn_SP"]

# %%
model_types = ["rbc"]
data_lengths = [5, 10, 20]
windows = [
    [dt.date(1999, 12, 31), dt.date(2025, 9, 30)],
    [dt.date(1999, 12, 31), dt.date(2007, 12, 31)],
    [dt.date(2007, 12, 31), dt.date(2009, 12, 31)],
    [dt.date(2009, 12, 31), dt.date(2019, 12, 31)],
    [dt.date(2019, 12, 31), dt.date(2022, 12, 31)],
    [dt.date(2022, 12, 31), dt.date(2025, 9, 30)],
]
signal_lags = [10, 20, 30]
leverage_cases = [1, 2]
double_down_cases = [False, True]

results = {}
for model_type in model_types:
    rbc = Model(
        model_type, 
        data_10y_19991231_20250930.prod, 
        data_10y_19991231_20250930.gdp, 
        [data_10y_19991231_20250930.asset_sp500, data_10y_19991231_20250930.asset_dow],
        ["SP", "DOW"],
        data_10y_19991231_20250930.holidays
    )

    bh = BuyAndHold(
        [data_10y_19991231_20250930.asset_sp500, data_10y_19991231_20250930.asset_dow],
        ["SP", "DOW"]
    )

    for window in windows:
        window_str = str(window[0]) + "_" + str(window[1])
        results[window_str] = {}
    
        for data_length in data_lengths:
            for signal_lag in signal_lags:
                for leverage in leverage_cases:
                    for double_down in double_down_cases:
                        if not ((data_length == 20) & (window[0] < dt.date(2009, 12, 31))): # GDP data is unavailable before 1989-12-29 so avoid sourcing data before then
                            signals = rbc.generate_signals(data_length, window[0], window[1], leverage, double_down)
                            strategy = rbc.run_strategy(signals, signal_lag, window[0], window[1])
                            
                            key = model_type + "_" + str(data_length) + "cal_" + window_str + "_" + str(signal_lag) + "lag"
                            if leverage > 1:
                                key += "_" + str(leverage) + "lev"
                            if double_down == True:
                                key += "_dd"
                            
                            results[window_str][key] = {"signals": signals, "strategy": strategy}

        strategy_bh = bh.run_strategy(window[0], window[1])
        
        key_bh = "bh_" + window_str
        results[window_str][key_bh] = {"strategy": strategy_bh}
# Out:
# window_prod:
#
#              OPHNFB
# DATE
# 1999-09-30   70.469
# 1999-12-31   71.516
# 2000-03-31   71.222
# 2000-06-30   72.657
# 2000-09-29   72.587
# ...             ...
# 2024-06-28  114.947
# 2024-09-30  115.989
# 2024-12-31  116.394
# 2025-03-31  116.127
# 2025-06-30  117.319
#
# [104 rows x 1 columns]
# Estimated rho: 0.746
# Estimated TFP shock for 1999-09-30: 0.0038
# <dolo.numeric.distribution.UNormal object at 0x00000156668E0B50>
# 10 [0.00378041]
# Next period IRF forecast as of 1999-09-30: 0.00004
# Estimated rho: 0.716
# Estimated TFP shock for 1999-12-31: 0.0089
# <dolo.numeric.distribution.UNormal object at 0x000001569962C990>
# 10 [0.00891529]
# Next period IRF forecast as of 1999-12-31: 0.00697
# Estimated rho: 0.586
# Estimated TFP shock for 2000-03-31: -0.0067
# <dolo.numeric.distribution.UNormal object at 0x000001566F99A050>
# 10 [-0.00668182]
# Next period IRF forecast as of 2000-03-31: -0.01405
# Estimated rho: 0.461
# Estimated TFP shock for 2000-06-30: 0.0107
# <dolo.numeric.distribution.UNormal object at 0x00000156630A3610>
# 10 [0.01069896]
# Next period IRF forecast as of 2000-06-30: 0.01003
# Estimated rho: 0.407
# Estimated TFP shock for 2000-09-29: -0.0037
# <dolo.numeric.distribution.UNormal object at 0x00000156A5CDD790>
# 10 [-0.00365668]
# Next period IRF forecast as of 2000-09-29: -0.01004
# Estimated rho: 0.365
# Estimated TFP shock for 2000-12-29: 0.0019
# <dolo.numeric.distribution.UNormal object at 0x000001568B7C7890>
# 10 [0.00193802]
# Next period IRF forecast as of 2000-12-29: -0.00222
# Estimated rho: 0.299
# Estimated TFP shock for 2001-03-30: -0.0109
# <dolo.numeric.distribution.UNormal object at 0x00000156119504D0>
# 10 [-0.01091605]
# Next period IRF forecast as of 2001-03-30: -0.02021
# Estimated rho: 0.169
# Estimated TFP shock for 2001-06-29: 0.0009
# <dolo.numeric.distribution.UNormal object at 0x00000156A9BD0390>
# 10 [0.00086442]
# Next period IRF forecast as of 2001-06-29: -0.00372
# Estimated rho: 0.009
# Estimated TFP shock for 2001-09-28: -0.0030
# <dolo.numeric.distribution.UNormal object at 0x00000156765C3010>
# 10 [-0.00298211]
# Next period IRF forecast as of 2001-09-28: -0.00918
# Estimated rho: -0.115
# Estimated TFP shock for 2001-12-31: 0.0005
# <dolo.numeric.distribution.UNormal object at 0x0000015676AD8890>
# 10 [0.00045608]
# Next period IRF forecast as of 2001-12-31: -0.00429
# Estimated rho: -0.013
# Estimated TFP shock for 2002-03-29: 0.0106
# <dolo.numeric.distribution.UNormal object at 0x000001567669AED0>
# 10 [0.0105725]
# Next period IRF forecast as of 2002-03-29: 0.01024
# Estimated rho: 0.082
# Estimated TFP shock for 2002-06-28: 0.0026
# <dolo.numeric.distribution.UNormal object at 0x00000156A9D028D0>
# 10 [0.00257716]
# Next period IRF forecast as of 2002-06-28: -0.00127
# Estimated rho: 0.092
# Estimated TFP shock for 2002-09-30: 0.0019
# <dolo.numeric.distribution.UNormal object at 0x00000156760CC150>
# 10 [0.00187104]
# Next period IRF forecast as of 2002-09-30: -0.00228
# Estimated rho: 0.067
# Estimated TFP shock for 2002-12-31: -0.0062
# <dolo.numeric.distribution.UNormal object at 0x000001568B51E950>
# 10 [-0.00623939]
# Next period IRF forecast as of 2002-12-31: -0.01378
# Estimated rho: 0.097
# Estimated TFP shock for 2003-03-31: -0.0028
# <dolo.numeric.distribution.UNormal object at 0x00000156A9CB77D0>
# 10 [-0.00284418]
# Next period IRF forecast as of 2003-03-31: -0.00898
# Estimated rho: 0.065
# Estimated TFP shock for 2003-06-30: 0.0017
# <dolo.numeric.distribution.UNormal object at 0x00000156A9DF9890>
# 10 [0.00170561]
# Next period IRF forecast as of 2003-06-30: -0.00251
# Estimated rho: 0.076
# Estimated TFP shock for 2003-09-30: 0.0124
# <dolo.numeric.distribution.UNormal object at 0x0000015699B96BD0>
# 10 [0.01238421]
# Next period IRF forecast as of 2003-09-30: 0.01281
# Estimated rho: 0.248
# Estimated TFP shock for 2003-12-31: 0.0082
# <dolo.numeric.distribution.UNormal object at 0x0000015675FD8750>
# 10 [0.00816403]
# Next period IRF forecast as of 2003-12-31: 0.00664
# Estimated rho: 0.209
# Estimated TFP shock for 2004-03-31: -0.0030
# <dolo.numeric.distribution.UNormal object at 0x0000015666876490>
# 10 [-0.0030487]
# Next period IRF forecast as of 2004-03-31: -0.00925
# Estimated rho: 0.213
# Estimated TFP shock for 2004-06-30: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x00000156A9CF77D0>
# 10 [0.00069321]
# Next period IRF forecast as of 2004-06-30: -0.00396
# Estimated rho: 0.213
# Estimated TFP shock for 2004-09-30: -0.0032
# <dolo.numeric.distribution.UNormal object at 0x00000156AAF83B10>
# 10 [-0.00319174]
# Next period IRF forecast as of 2004-09-30: -0.00945
# Estimated rho: 0.217
# Estimated TFP shock for 2004-12-31: -0.0054
# <dolo.numeric.distribution.UNormal object at 0x000001560FFEAD10>
# 10 [-0.00538704]
# Next period IRF forecast as of 2004-12-31: -0.01253
# Estimated rho: 0.286
# Estimated TFP shock for 2005-03-31: -0.0018
# <dolo.numeric.distribution.UNormal object at 0x00000156AAFF7650>
# 10 [-0.00182505]
# Next period IRF forecast as of 2005-03-31: -0.00751
# Estimated rho: 0.347
# Estimated TFP shock for 2005-06-30: -0.0096
# <dolo.numeric.distribution.UNormal object at 0x00000156AAE09750>
# 10 [-0.00964685]
# Next period IRF forecast as of 2005-06-30: -0.01840
# Estimated rho: 0.436
# Estimated TFP shock for 2005-09-30: -0.0058
# <dolo.numeric.distribution.UNormal object at 0x00000156AAF7ED10>
# 10 [-0.00583342]
# Next period IRF forecast as of 2005-09-30: -0.01304
# Estimated rho: 0.518
# Estimated TFP shock for 2005-12-30: -0.0105
# <dolo.numeric.distribution.UNormal object at 0x00000156AAF40350>
# 10 [-0.01045987]
# Next period IRF forecast as of 2005-12-30: -0.01930
# Estimated rho: 0.589
# Estimated TFP shock for 2006-03-31: -0.0050
# <dolo.numeric.distribution.UNormal object at 0x00000156AAFB5CD0>
# 10 [-0.00495403]
# Next period IRF forecast as of 2006-03-31: -0.01170
# Estimated rho: 0.673
# Estimated TFP shock for 2006-06-30: -0.0101
# <dolo.numeric.distribution.UNormal object at 0x00000156AB1764D0>
# 10 [-0.01008911]
# Next period IRF forecast as of 2006-06-30: -0.01843
# Estimated rho: 0.692
# Estimated TFP shock for 2006-09-29: -0.0111
# <dolo.numeric.distribution.UNormal object at 0x00000156AAF0C2D0>
# 10 [-0.01108708]
# Next period IRF forecast as of 2006-09-29: -0.01968
# Estimated rho: 0.688
# Estimated TFP shock for 2006-12-29: -0.0035
# <dolo.numeric.distribution.UNormal object at 0x000001566659F010>
# 10 [-0.00347548]
# Next period IRF forecast as of 2006-12-29: -0.00959
# Estimated rho: 0.796
# Estimated TFP shock for 2007-03-30: -0.0035
# <dolo.numeric.distribution.UNormal object at 0x00000156AB221E10>
# 10 [-0.00352132]
# Next period IRF forecast as of 2007-03-30: -0.00945
# Estimated rho: 0.789
# Estimated TFP shock for 2007-06-29: -0.0036
# <dolo.numeric.distribution.UNormal object at 0x00000156AAFF66D0>
# 10 [-0.00360917]
# Next period IRF forecast as of 2007-06-29: -0.00958
# Estimated rho: 0.755
# Estimated TFP shock for 2007-09-28: 0.0020
# <dolo.numeric.distribution.UNormal object at 0x00000156AB0B6890>
# 10 [0.00202905]
# Next period IRF forecast as of 2007-09-28: -0.00228
# Estimated rho: 0.657
# Estimated TFP shock for 2007-12-31: 0.0021
# <dolo.numeric.distribution.UNormal object at 0x00000156A9CD6550>
# 10 [0.00206786]
# Next period IRF forecast as of 2007-12-31: -0.00215
# Estimated rho: 0.479
# Estimated TFP shock for 2008-03-31: -0.0092
# <dolo.numeric.distribution.UNormal object at 0x00000156AB249990>
# 10 [-0.00922776]
# Next period IRF forecast as of 2008-03-31: -0.01768
# Estimated rho: 0.201
# Estimated TFP shock for 2008-06-30: 0.0024
# <dolo.numeric.distribution.UNormal object at 0x00000156AB335650>
# 10 [0.00241928]
# Next period IRF forecast as of 2008-06-30: -0.00151
# Estimated rho: 0.201
# Estimated TFP shock for 2008-09-30: 0.0004
# <dolo.numeric.distribution.UNormal object at 0x00000156AB598090>
# 10 [0.00035711]
# Next period IRF forecast as of 2008-09-30: -0.00444
# Estimated rho: 0.172
# Estimated TFP shock for 2008-12-31: -0.0068
# <dolo.numeric.distribution.UNormal object at 0x00000156AB065090>
# 10 [-0.00676311]
# Next period IRF forecast as of 2008-12-31: -0.01448
# Estimated rho: 0.103
# Estimated TFP shock for 2009-03-31: 0.0019
# <dolo.numeric.distribution.UNormal object at 0x00000156AB5B7250>
# 10 [0.00185379]
# Next period IRF forecast as of 2009-03-31: -0.00231
# Estimated rho: 0.097
# Estimated TFP shock for 2009-06-30: 0.0167
# <dolo.numeric.distribution.UNormal object at 0x00000156AB27B690>
# 10 [0.01668513]
# Next period IRF forecast as of 2009-06-30: 0.01901
# Estimated rho: 0.649
# Estimated TFP shock for 2009-09-30: 0.0151
# <dolo.numeric.distribution.UNormal object at 0x00000156AB2A5D10>
# 10 [0.01508092]
# Next period IRF forecast as of 2009-09-30: 0.01564
# Estimated rho: 0.833
# Estimated TFP shock for 2009-12-31: 0.0108
# <dolo.numeric.distribution.UNormal object at 0x00000156AB36E3D0>
# 10 [0.01081592]
# Next period IRF forecast as of 2009-12-31: 0.00867
# Estimated rho: 0.772
# Estimated TFP shock for 2010-03-31: -0.0001
# <dolo.numeric.distribution.UNormal object at 0x00000156993BFF10>
# 10 [-0.00011267]
# Next period IRF forecast as of 2010-03-31: -0.00509
# Estimated rho: 0.764
# Estimated TFP shock for 2010-06-30: 0.0001
# <dolo.numeric.distribution.UNormal object at 0x00000156A9BCFC50>
# 10 [6.51783453e-05]
# Next period IRF forecast as of 2010-06-30: -0.00486
# Estimated rho: 0.733
# Estimated TFP shock for 2010-09-30: 0.0019
# <dolo.numeric.distribution.UNormal object at 0x00000156AB799590>
# 10 [0.00188312]
# Next period IRF forecast as of 2010-09-30: -0.00245
# Estimated rho: 0.719
# Estimated TFP shock for 2010-12-31: -0.0019
# <dolo.numeric.distribution.UNormal object at 0x00000156630BDCD0>
# 10 [-0.00191603]
# Next period IRF forecast as of 2010-12-31: -0.00748
# Estimated rho: 0.662
# Estimated TFP shock for 2011-03-31: -0.0126
# <dolo.numeric.distribution.UNormal object at 0x00000156AB36E290>
# 10 [-0.01262001]
# Next period IRF forecast as of 2011-03-31: -0.02183
# Estimated rho: 0.708
# Estimated TFP shock for 2011-06-30: -0.0079
# <dolo.numeric.distribution.UNormal object at 0x00000156AB454810>
# 10 [-0.00792694]
# Next period IRF forecast as of 2011-06-30: -0.01545
# Estimated rho: 0.789
# Estimated TFP shock for 2011-09-30: -0.0098
# <dolo.numeric.distribution.UNormal object at 0x00000156AB66F710>
# 10 [-0.00978738]
# Next period IRF forecast as of 2011-09-30: -0.01748
# Estimated rho: 0.802
# Estimated TFP shock for 2011-12-30: -0.0035
# <dolo.numeric.distribution.UNormal object at 0x00000156AB70DBD0>
# 10 [-0.00347188]
# Next period IRF forecast as of 2011-12-30: -0.00937
# Estimated rho: 0.808
# Estimated TFP shock for 2012-03-30: -0.0024
# <dolo.numeric.distribution.UNormal object at 0x00000156AB734390>
# 10 [-0.00242597]
# Next period IRF forecast as of 2012-03-30: -0.00803
# Estimated rho: 0.809
# Estimated TFP shock for 2012-06-29: -0.0016
# <dolo.numeric.distribution.UNormal object at 0x00000156AB065090>
# 10 [-0.0015677]
# Next period IRF forecast as of 2012-06-29: -0.00694
# Estimated rho: 0.825
# Estimated TFP shock for 2012-09-28: -0.0085
# <dolo.numeric.distribution.UNormal object at 0x00000156AB5EAED0>
# 10 [-0.00846295]
# Next period IRF forecast as of 2012-09-28: -0.01554
# Estimated rho: 0.847
# Estimated TFP shock for 2012-12-31: -0.0091
# <dolo.numeric.distribution.UNormal object at 0x00000156666D1190>
# 10 [-0.0091305]
# Next period IRF forecast as of 2012-12-31: -0.01616
# Estimated rho: 0.836
# Estimated TFP shock for 2013-03-29: -0.0010
# <dolo.numeric.distribution.UNormal object at 0x00000156AB6B2E90>
# 10 [-0.00095311]
# Next period IRF forecast as of 2013-03-29: -0.00613
# Estimated rho: 0.851
# Estimated TFP shock for 2013-06-28: -0.0067
# <dolo.numeric.distribution.UNormal object at 0x00000156ABAB7A50>
# 10 [-0.00674578]
# Next period IRF forecast as of 2013-06-28: -0.01321
# Estimated rho: 0.805
# Estimated TFP shock for 2013-09-30: 0.0022
# <dolo.numeric.distribution.UNormal object at 0x00000156AB943450>
# 10 [0.00215493]
# Next period IRF forecast as of 2013-09-30: -0.00219
# Estimated rho: 0.678
# Estimated TFP shock for 2013-12-31: 0.0051
# <dolo.numeric.distribution.UNormal object at 0x00000156A9CE2F90>
# 10 [0.00505277]
# Next period IRF forecast as of 2013-12-31: 0.00187
# Estimated rho: 0.480
# Estimated TFP shock for 2014-03-31: -0.0081
# <dolo.numeric.distribution.UNormal object at 0x00000156667B4710>
# 10 [-0.00812085]
# Next period IRF forecast as of 2014-03-31: -0.01615
# Estimated rho: 0.349
# Estimated TFP shock for 2014-06-30: 0.0021
# <dolo.numeric.distribution.UNormal object at 0x00000156AB4FBCD0>
# 10 [0.00205705]
# Next period IRF forecast as of 2014-06-30: -0.00205
# Estimated rho: 0.225
# Estimated TFP shock for 2014-09-30: 0.0069
# <dolo.numeric.distribution.UNormal object at 0x00000156A94B3890>
# 10 [0.00692106]
# Next period IRF forecast as of 2014-09-30: 0.00488
# Estimated rho: 0.276
# Estimated TFP shock for 2014-12-31: -0.0000
# <dolo.numeric.distribution.UNormal object at 0x00000156ABA70D10>
# 10 [-3.03983942e-05]
# Next period IRF forecast as of 2014-12-31: -0.00498
# Estimated rho: 0.284
# Estimated TFP shock for 2015-03-31: 0.0044
# <dolo.numeric.distribution.UNormal object at 0x00000156AB9D3AD0>
# 10 [0.00440035]
# Next period IRF forecast as of 2015-03-31: 0.00127
# Estimated rho: 0.331
# Estimated TFP shock for 2015-06-30: 0.0049
# <dolo.numeric.distribution.UNormal object at 0x00000156AB00ACD0>
# 10 [0.00491348]
# Next period IRF forecast as of 2015-06-30: 0.00198
# Estimated rho: 0.344
# Estimated TFP shock for 2015-09-30: 0.0035
# <dolo.numeric.distribution.UNormal object at 0x00000156AB73EB10>
# 10 [0.00352486]
# Next period IRF forecast as of 2015-09-30: 0.00002
# Estimated rho: 0.150
# Estimated TFP shock for 2015-12-31: -0.0039
# <dolo.numeric.distribution.UNormal object at 0x00000156A9D003D0>
# 10 [-0.00390215]
# Next period IRF forecast as of 2015-12-31: -0.01046
# Estimated rho: 0.144
# Estimated TFP shock for 2016-03-31: -0.0010
# <dolo.numeric.distribution.UNormal object at 0x00000156ABB9F4D0>
# 10 [-0.00101949]
# Next period IRF forecast as of 2016-03-31: -0.00639
# Estimated rho: 0.152
# Estimated TFP shock for 2016-06-30: -0.0026
# <dolo.numeric.distribution.UNormal object at 0x00000156AB797A50>
# 10 [-0.0025597]
# Next period IRF forecast as of 2016-06-30: -0.00857
# Estimated rho: 0.180
# Estimated TFP shock for 2016-09-30: -0.0009
# <dolo.numeric.distribution.UNormal object at 0x00000156ABDD4F10>
# 10 [-0.00091716]
# Next period IRF forecast as of 2016-09-30: -0.00624
# Estimated rho: 0.167
# Estimated TFP shock for 2016-12-30: 0.0029
# <dolo.numeric.distribution.UNormal object at 0x00000156AB8D1B90>
# 10 [0.00288325]
# Next period IRF forecast as of 2016-12-30: -0.00085
# Estimated rho: 0.173
# Estimated TFP shock for 2017-03-31: 0.0011
# <dolo.numeric.distribution.UNormal object at 0x00000156AB9BC0D0>
# 10 [0.00107185]
# Next period IRF forecast as of 2017-03-31: -0.00342
# Estimated rho: 0.083
# Estimated TFP shock for 2017-06-30: -0.0006
# <dolo.numeric.distribution.UNormal object at 0x00000156ABB36190>
# 10 [-0.00062405]
# Next period IRF forecast as of 2017-06-30: -0.00583
# Estimated rho: -0.049
# Estimated TFP shock for 2017-09-29: 0.0036
# <dolo.numeric.distribution.UNormal object at 0x00000156AB9D2450>
# 10 [0.00356194]
# Next period IRF forecast as of 2017-09-29: 0.00015
# Estimated rho: 0.101
# Estimated TFP shock for 2017-12-29: 0.0062
# <dolo.numeric.distribution.UNormal object at 0x00000156ABB41B10>
# 10 [0.00621896]
# Next period IRF forecast as of 2017-12-29: 0.00393
# Estimated rho: 0.230
# Estimated TFP shock for 2018-03-30: 0.0043
# <dolo.numeric.distribution.UNormal object at 0x00000156ABA33190>
# 10 [0.00429319]
# Next period IRF forecast as of 2018-03-30: 0.00114
# Estimated rho: 0.267
# Estimated TFP shock for 2018-06-29: 0.0007
# <dolo.numeric.distribution.UNormal object at 0x00000156ABD0C390>
# 10 [0.00073672]
# Next period IRF forecast as of 2018-06-29: -0.00390
# Estimated rho: 0.271
# Estimated TFP shock for 2018-09-28: 0.0013
# <dolo.numeric.distribution.UNormal object at 0x00000156ABD2AF50>
# 10 [0.00129542]
# Next period IRF forecast as of 2018-09-28: -0.00311
# Estimated rho: 0.273
# Estimated TFP shock for 2018-12-31: -0.0030
# <dolo.numeric.distribution.UNormal object at 0x00000156ABE7B890>
# 10 [-0.00298219]
# Next period IRF forecast as of 2018-12-31: -0.00914
# Estimated rho: 0.396
# Estimated TFP shock for 2019-03-29: 0.0034
# <dolo.numeric.distribution.UNormal object at 0x00000156AB7C61D0>
# 10 [0.00335995]
# Next period IRF forecast as of 2019-03-29: -0.00023
# Estimated rho: 0.422
# Estimated TFP shock for 2019-06-28: 0.0037
# <dolo.numeric.distribution.UNormal object at 0x00000156ABD28450>
# 10 [0.00373356]
# Next period IRF forecast as of 2019-06-28: 0.00028
# Estimated rho: 0.499
# Estimated TFP shock for 2019-09-30: 0.0087
# <dolo.numeric.distribution.UNormal object at 0x00000156AB794850>
# 10 [0.00872778]
# Next period IRF forecast as of 2019-09-30: 0.00721
# Estimated rho: 0.738
# Estimated TFP shock for 2019-12-31: 0.0071
# <dolo.numeric.distribution.UNormal object at 0x00000156AB29A510>
# 10 [0.0071477]
# Next period IRF forecast as of 2019-12-31: 0.00452
# Estimated rho: 0.590
# Estimated TFP shock for 2020-03-31: -0.0035
# <dolo.numeric.distribution.UNormal object at 0x00000156AC103B10>
# 10 [-0.0034856]
# Next period IRF forecast as of 2020-03-31: -0.00970
# Estimated rho: 0.276
# Estimated TFP shock for 2020-06-30: 0.0380
# <dolo.numeric.distribution.UNormal object at 0x00000156A5340D10>
# 10 [0.03801699]
# Next period IRF forecast as of 2020-06-30: 0.04992
# Estimated rho: 0.719
# Estimated TFP shock for 2020-09-30: 0.0168
# <dolo.numeric.distribution.UNormal object at 0x00000156ABAD77D0>
# 10 [0.01684455]
# Next period IRF forecast as of 2020-09-30: 0.01765
# Estimated rho: 0.655
# Estimated TFP shock for 2020-12-31: -0.0042
# <dolo.numeric.distribution.UNormal object at 0x00000156AC0B1690>
# 10 [-0.00416718]
# Next period IRF forecast as of 2020-12-31: -0.01056
# Estimated rho: 0.647
# Estimated TFP shock for 2021-03-31: 0.0043
# <dolo.numeric.distribution.UNormal object at 0x000001560FFEAD10>
# 10 [0.00428708]
# Next period IRF forecast as of 2021-03-31: 0.00087
# Estimated rho: 0.633
# Estimated TFP shock for 2021-06-30: -0.0017
# <dolo.numeric.distribution.UNormal object at 0x00000156AC097710>
# 10 [-0.00167492]
# Next period IRF forecast as of 2021-06-30: -0.00721
# Estimated rho: 0.613
# Estimated TFP shock for 2021-09-30: -0.0112
# <dolo.numeric.distribution.UNormal object at 0x00000156A926FC10>
# 10 [-0.01120997]
# Next period IRF forecast as of 2021-09-30: -0.02011
# Estimated rho: 0.608
# Estimated TFP shock for 2021-12-31: -0.0041
# <dolo.numeric.distribution.UNormal object at 0x00000156AB82A790>
# 10 [-0.00410052]
# Next period IRF forecast as of 2021-12-31: -0.01052
# Estimated rho: 0.644
# Estimated TFP shock for 2022-03-31: -0.0206
# <dolo.numeric.distribution.UNormal object at 0x00000156ABA70D10>
# 10 [-0.02055975]
# Next period IRF forecast as of 2022-03-31: -0.03243
# Estimated rho: 0.739
# Estimated TFP shock for 2022-06-30: -0.0176
# <dolo.numeric.distribution.UNormal object at 0x00000156A933CE90>
# 10 [-0.01763999]
# Next period IRF forecast as of 2022-06-30: -0.02794
# Estimated rho: 0.781
# Estimated TFP shock for 2022-09-30: -0.0097
# <dolo.numeric.distribution.UNormal object at 0x00000156AC3396D0>
# 10 [-0.00974887]
# Next period IRF forecast as of 2022-09-30: -0.01748
# Estimated rho: 0.784
# Estimated TFP shock for 2022-12-30: -0.0039
# <dolo.numeric.distribution.UNormal object at 0x00000156AC1CF810>
# 10 [-0.00391972]
# Next period IRF forecast as of 2022-12-30: -0.00999
# Estimated rho: 0.792
# Estimated TFP shock for 2023-03-31: -0.0055
# <dolo.numeric.distribution.UNormal object at 0x00000156AC220B90>
# 10 [-0.00554974]
# Next period IRF forecast as of 2023-03-31: -0.01206
# Estimated rho: 0.780
# Estimated TFP shock for 2023-06-30: 0.0024
# <dolo.numeric.distribution.UNormal object at 0x00000156AC1A3250>
# 10 [0.00240751]
# Next period IRF forecast as of 2023-06-30: -0.00182
# Estimated rho: 0.765
# Estimated TFP shock for 2023-09-29: 0.0063
# <dolo.numeric.distribution.UNormal object at 0x00000156AC4A0610>
# 10 [0.00626335]
# Next period IRF forecast as of 2023-09-29: 0.00325
# Estimated rho: 0.747
# Estimated TFP shock for 2023-12-29: 0.0055
# <dolo.numeric.distribution.UNormal object at 0x00000156AC51FFD0>
# 10 [0.00551603]
# Next period IRF forecast as of 2023-12-29: 0.00233
# Estimated rho: 0.728
# Estimated TFP shock for 2024-03-29: -0.0016
# <dolo.numeric.distribution.UNormal object at 0x00000156AB8AD410>
# 10 [-0.00159787]
# Next period IRF forecast as of 2024-03-29: -0.00705
# Estimated rho: 0.698
# Estimated TFP shock for 2024-06-28: 0.0061
# <dolo.numeric.distribution.UNormal object at 0x00000156ABDC7ED0>
# 10 [0.00606339]
# Next period IRF forecast as of 2024-06-28: 0.00319
# Estimated rho: 0.682
# Estimated TFP shock for 2024-09-30: 0.0073
# <dolo.numeric.distribution.UNormal object at 0x00000156AB8F7D90>
# 10 [0.00728637]
# Next period IRF forecast as of 2024-09-30: 0.00488
# Estimated rho: 0.651
# Estimated TFP shock for 2024-12-31: 0.0034
# <dolo.numeric.distribution.UNormal object at 0x00000156AC1CECD0>
# 10 [0.0033847]
# Next period IRF forecast as of 2024-12-31: -0.00036
# Estimated rho: 0.509
# Estimated TFP shock for 2025-03-31: -0.0008
# <dolo.numeric.distribution.UNormal object at 0x00000156AC809E90>
# 10 [-0.0007721]
# Next period IRF forecast as of 2025-03-31: -0.00601
# Estimated rho: 0.820
# Estimated TFP shock for 2025-06-30: 0.0073
# <dolo.numeric.distribution.UNormal object at 0x00000156ABFE4B90>
# 10 [0.00725587]
# Next period IRF forecast as of 2025-06-30: 0.00427
# \window_gdp:
#
#                 GDPC1
# DATE
# 1999-12-31  13827.980
# 2000-03-31  13878.147
# 2000-06-30  14130.908
# 2000-09-29  14145.312
# 2000-12-29  14229.765
# ...               ...
# 2024-09-30  23478.570
# 2024-12-31  23586.542
# 2025-03-31  23548.210
# 2025-06-30  23770.976
# 2025-09-30  24026.834
#
# [104 rows x 1 columns]
# Current period realised value as of 1999-12-31: 0.00737
# Current period realised value as of 2000-03-31: -0.00075
# Current period realised value as of 2000-06-30: 0.00434
# Current period realised value as of 2000-09-29: -0.00494
# Current period realised value as of 2000-12-29: -0.00820
# Current period realised value as of 2001-03-30: -0.01765
# Current period realised value as of 2001-06-29: -0.01691
# Current period realised value as of 2001-09-28: -0.02419
# Current period realised value as of 2001-12-31: -0.02381
# Current period realised value as of 2002-03-29: -0.01837
# Current period realised value as of 2002-06-28: -0.01494
# Current period realised value as of 2002-09-30: -0.01358
# Current period realised value as of 2002-12-31: -0.01433
# Current period realised value as of 2003-03-31: -0.01110
# Current period realised value as of 2003-06-30: -0.00523
# Current period realised value as of 2003-09-30: 0.00588
# Current period realised value as of 2003-12-31: 0.01068
# Current period realised value as of 2004-03-31: 0.00936
# Current period realised value as of 2004-06-30: 0.00981
# Current period realised value as of 2004-09-30: 0.01139
# Current period realised value as of 2004-12-31: 0.01270
# Current period realised value as of 2005-03-31: 0.01357
# Current period realised value as of 2005-06-30: 0.00912
# Current period realised value as of 2005-09-30: 0.00681
# Current period realised value as of 2005-12-30: 0.00296
# Current period realised value as of 2006-03-31: 0.00567
# Current period realised value as of 2006-06-30: -0.00064
# Current period realised value as of 2006-09-29: -0.00670
# Current period realised value as of 2006-12-29: -0.00538
# Current period realised value as of 2007-03-30: -0.00843
# Current period realised value as of 2007-06-29: -0.00829
# Current period realised value as of 2007-09-28: -0.00824
# Current period realised value as of 2007-12-31: -0.00741
# Current period realised value as of 2008-03-31: -0.01444
# Current period realised value as of 2008-06-30: -0.01122
# Current period realised value as of 2008-09-30: -0.01700
# Current period realised value as of 2008-12-31: -0.03463
# Reading IRF forecast as of 2023-12-29 with 5 years of calibration
# Reading IRF forecast as of 2024-03-29 with 5 years of calibration
# Reading IRF forecast as of 2024-06-28 with 5 years of calibration
# Reading IRF forecast as of 2024-09-30 with 5 years of calibration
# Reading IRF forecast as of 2024-12-31 with 5 years of calibration
# Reading IRF forecast as of 2025-03-31 with 5 years of calibration
# Reading IRF forecast as of 2025-06-30 with 5 years of calibration
# \window_gdp:
#
#                 GDPC1
# DATE
# 1999-12-31  13827.980
# 2000-03-31  13878.147
# 2000-06-30  14130.908
# 2000-09-29  14145.312
# 2000-12-29  14229.765
# ...               ...
# 2024-09-30  23478.570
# 2024-12-31  23586.542
# 2025-03-31  23548.210
# 2025-06-30  23770.976
# 2025-09-30  24026.834
#
# [104 rows x 1 columns]
# Reading realised value as of 1999-12-31 with 5 years of calibration
# Reading realised value as of 2000-03-31 with 5 years of calibration
# Reading realised value as of 2000-06-30 with 5 years of calibration
# Reading realised value as of 2000-09-29 with 5 years of calibration
# Reading realised value as of 2000-12-29 with 5 years of calibration
# Reading realised value as of 2001-03-30 with 5 years of calibration
# Reading realised value as of 2001-06-29 with 5 years of calibration
# Reading realised value as of 2001-09-28 with 5 years of calibration
# Reading realised value as of 2001-12-31 with 5 years of calibration
# Reading realised value as of 2002-03-29 with 5 years of calibration
# Reading realised value as of 2002-06-28 with 5 years of calibration
# Reading realised value as of 2002-09-30 with 5 years of calibration
# Reading realised value as of 2002-12-31 with 5 years of calibration
# Reading realised value as of 2003-03-31 with 5 years of calibration
# Reading realised value as of 2003-06-30 with 5 years of calibration
# Reading realised value as of 2003-09-30 with 5 years of calibration
# Reading realised value as of 2003-12-31 with 5 years of calibration
# Reading realised value as of 2004-03-31 with 5 years of calibration
# Reading realised value as of 2004-06-30 with 5 years of calibration
# Reading realised value as of 2004-09-30 with 5 years of calibration
# Reading realised value as of 2004-12-31 with 5 years of calibration
# Reading realised value as of 2005-03-31 with 5 years of calibration
# Reading realised value as of 2005-06-30 with 5 years of calibration
# Reading realised value as of 2005-09-30 with 5 years of calibration
# Reading realised value as of 2005-12-30 with 5 years of calibration
# Reading realised value as of 2006-03-31 with 5 years of calibration
# Reading realised value as of 2006-06-30 with 5 years of calibration
# Reading realised value as of 2006-09-29 with 5 years of calibration
# Reading realised value as of 2006-12-29 with 5 years of calibration
# Reading realised value as of 2007-03-30 with 5 years of calibration
# Reading realised value as of 2007-06-29 with 5 years of calibration
# Reading realised value as of 2007-09-28 with 5 years of calibration
# Reading realised value as of 2007-12-31 with 5 years of calibration
# Reading realised value as of 2008-03-31 with 5 years of calibration
# Reading realised value as of 2008-06-30 with 5 years of calibration
# Reading realised value as of 2008-09-30 with 5 years of calibration
# Reading realised value as of 2008-12-31 with 5 years of calibration
# Reading realised value as of 2009-03-31 with 5 years of calibration
# Reading realised value as of 2009-06-30 with 5 years of calibration
# Reading realised value as of 2009-09-30 with 5 years of calibration
# Reading realised value as of 2009-12-31 with 5 years of calibration
# Reading realised value as of 2010-03-31 with 5 years of calibration
# Reading realised value as of 2010-06-30 with 5 years of calibration
# Reading realised value as of 2010-09-30 with 5 years of calibration
# Reading realised value as of 2010-12-31 with 5 years of calibration
# Reading realised value as of 2011-03-31 with 5 years of calibration
# Reading realised value as of 2011-06-30 with 5 years of calibration
# Reading realised value as of 2011-09-30 with 5 years of calibration
# Reading realised value as of 2011-12-30 with 5 years of calibration
# Reading realised value as of 2012-03-30 with 5 years of calibration
# Reading realised value as of 2012-06-29 with 5 years of calibration
# Reading realised value as of 2012-09-28 with 5 years of calibration
# Reading realised value as of 2012-12-31 with 5 years of calibration
# Reading realised value as of 2013-03-29 with 5 years of calibration
# Reading realised value as of 2013-06-28 with 5 years of calibration
# Reading realised value as of 2013-09-30 with 5 years of calibration
# Reading realised value as of 2013-12-31 with 5 years of calibration
# Reading realised value as of 2014-03-31 with 5 years of calibration
# Reading realised value as of 2014-06-30 with 5 years of calibration
# Reading realised value as of 2014-09-30 with 5 years of calibration
# Reading realised value as of 2014-12-31 with 5 years of calibration
# Reading realised value as of 2015-03-31 with 5 years of calibration
# Reading realised value as of 2015-06-30 with 5 years of calibration
# Reading realised value as of 2015-09-30 with 5 years of calibration
# Reading realised value as of 2015-12-31 with 5 years of calibration
# Reading realised value as of 2016-03-31 with 5 years of calibration
# Reading realised value as of 2016-06-30 with 5 years of calibration
# Reading realised value as of 2016-09-30 with 5 years of calibration
# Reading realised value as of 2016-12-30 with 5 years of calibration
# Reading realised value as of 2017-03-31 with 5 years of calibration
# Reading realised value as of 2017-06-30 with 5 years of calibration
# Reading realised value as of 2017-09-29 with 5 years of calibration
# Reading realised value as of 2017-12-29 with 5 years of calibration
# Reading realised value as of 2018-03-30 with 5 years of calibration
# Reading realised value as of 2018-06-29 with 5 years of calibration
# Reading realised value as of 2018-09-28 with 5 years of calibration
# Reading realised value as of 2018-12-31 with 5 years of calibration
# Reading realised value as of 2019-03-29 with 5 years of calibration
# Reading realised value as of 2019-06-28 with 5 years of calibration
# Reading realised value as of 2019-09-30 with 5 years of calibration
# Reading realised value as of 2019-12-31 with 5 years of calibration
# Reading realised value as of 2020-03-31 with 5 years of calibration
# Reading realised value as of 2020-06-30 with 5 years of calibration
# Reading realised value as of 2020-09-30 with 5 years of calibration
# Reading realised value as of 2020-12-31 with 5 years of calibration
# Reading realised value as of 2021-03-31 with 5 years of calibration
# Reading realised value as of 2021-06-30 with 5 years of calibration
# Reading realised value as of 2021-09-30 with 5 years of calibration
# Reading realised value as of 2021-12-31 with 5 years of calibration
# Reading realised value as of 2022-03-31 with 5 years of calibration
# Reading realised value as of 2022-06-30 with 5 years of calibration
# Reading realised value as of 2022-09-30 with 5 years of calibration
# Reading realised value as of 2022-12-30 with 5 years of calibration
# Reading realised value as of 2023-03-31 with 5 years of calibration
# Reading realised value as of 2023-06-30 with 5 years of calibration
# Reading realised value as of 2023-09-29 with 5 years of calibration
# Reading realised value as of 2023-12-29 with 5 years of calibration
# Reading realised value as of 2024-03-29 with 5 years of calibration
# Reading realised value as of 2024-06-28 with 5 years of calibration
# Reading realised value as of 2024-09-30 with 5 years of calibration
# Reading realised value as of 2024-12-31 with 5 years of calibration
# Reading realised value as of 2025-03-31 with 5 years of calibration
# Reading realised value as of 2025-06-30 with 5 years of calibration
# Reading realised value as of 2025-09-30 with 5 years of calibration
#
# window_prod:
#
#              OPHNFB
# DATE
#
# 2024-06-28  23286.508
# 2024-09-30  23478.570
# 2024-12-31  23586.542
# 2025-03-31  23548.210
# 2025-06-30  23770.976
# 2025-09-30  24026.834
# Reading realised value as of 2023-03-31 with 20 years of calibration
# Reading realised value as of 2023-06-30 with 20 years of calibration
# Reading realised value as of 2023-09-29 with 20 years of calibration
# Reading realised value as of 2023-12-29 with 20 years of calibration
# Reading realised value as of 2024-03-29 with 20 years of calibration
# Reading realised value as of 2024-06-28 with 20 years of calibration
# Reading realised value as of 2024-09-30 with 20 years of calibration
# Reading realised value as of 2024-12-31 with 20 years of calibration
# Reading realised value as of 2025-03-31 with 20 years of calibration
# Reading realised value as of 2025-06-30 with 20 years of calibration
# Reading realised value as of 2025-09-30 with 20 years of calibration
#
# window_prod:
#
#              OPHNFB
# DATE
# 2022-09-30  109.422
# 2022-12-30  110.035
# 2023-03-31  110.269
# 2023-06-30  111.362
# 2023-09-29  112.738
# 2023-12-29  113.832
# 2024-03-29  113.902
# 2024-06-28  114.947
# 2024-09-30  115.989
# 2024-12-31  116.394
# 2025-03-31  116.127
# 2025-06-30  117.319
# Reading IRF forecast as of 2022-09-30 with 20 years of calibration
# Reading IRF forecast as of 2022-12-30 with 20 years of calibration
# Reading IRF forecast as of 2023-03-31 with 20 years of calibration
# Reading IRF forecast as of 2023-06-30 with 20 years of calibration
# Reading IRF forecast as of 2023-09-29 with 20 years of calibration
# Reading IRF forecast as of 2023-12-29 with 20 years of calibration
# Reading IRF forecast as of 2024-03-29 with 20 years of calibration
# Reading IRF forecast as of 2024-06-28 with 20 years of calibration
# Reading IRF forecast as of 2024-09-30 with 20 years of calibration
# Reading IRF forecast as of 2024-12-31 with 20 years of calibration
# Reading IRF forecast as of 2025-03-31 with 20 years of calibration
# Reading IRF forecast as of 2025-06-30 with 20 years of calibration
# \window_gdp:
#
#                 GDPC1
# DATE
# 2023-03-31  22439.607
# 2023-06-30  22580.499
# 2023-09-29  22840.989
# 2023-12-29  23033.780
# 2024-03-29  23082.119
# 2024-06-28  23286.508
# 2024-09-30  23478.570
# 2024-12-31  23586.542
# 2025-03-31  23548.210
# 2025-06-30  23770.976
# 2025-09-30  24026.834
# Reading realised value as of 2023-03-31 with 20 years of calibration
# Reading realised value as of 2023-06-30 with 20 years of calibration
# Reading realised value as of 2023-09-29 with 20 years of calibration
# Reading realised value as of 2023-12-29 with 20 years of calibration
# Reading realised value as of 2024-03-29 with 20 years of calibration
# Reading realised value as of 2024-06-28 with 20 years of calibration
# Reading realised value as of 2024-09-30 with 20 years of calibration
# Reading realised value as of 2024-12-31 with 20 years of calibration
# Reading realised value as of 2025-03-31 with 20 years of calibration
# Reading realised value as of 2025-06-30 with 20 years of calibration
# Reading realised value as of 2025-09-30 with 20 years of calibration

# %%
results
# Out:
# {'1999-12-31_2025-09-30': {'rbc_5cal_1999-12-31_2025-09-30_10lag': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  \
#    DATE
#    1999-12-31         0.007371         0.000039       -1       1
#    2000-03-31        -0.000752         0.006967        1      -1
#    2000-06-30         0.004342        -0.014049       -1       1
#    2000-09-29        -0.004938         0.010031        1      -1
#    2000-12-29        -0.008202        -0.010039       -1       1
#    ...                     ...              ...      ...     ...
#    2024-09-30        -0.000452         0.003187        1      -1
#    2024-12-31        -0.004528         0.004879        1      -1
#    2025-03-31        -0.013143        -0.000357        1      -1
#    2025-06-30        -0.010330        -0.006009        1      -1
#    2025-09-30        -0.001583         0.004267        1      -1
#
#                double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
#    DATE
#    1999-12-31                       1                      1             -1
#    2000-03-31                       1                      1              1
#    2000-06-30                       1                      1             -1
#    2000-09-29                       1                      1              1
#    2000-12-29                       1                      1             -1
#    ...                            ...                    ...            ...
#    2024-09-30                       1                      1              1
#    2024-12-31                       1                      1              1
#    2025-03-31                       1                      1              1
#    2025-06-30                       1                      1              1
#    2025-09-30                       1                      1              1
#
#                pos_final_mr
#    DATE
#    1999-12-31             1
#    2000-03-31            -1
#    2000-06-30             1
#    2000-09-29            -1
#    2000-12-29             1
#    ...                  ...
#    2024-09-30            -1
#    2024-12-31            -1
#    2025-03-31            -1
#    2025-06-30            -1
#    2025-09-30            -1
#
#    [104 rows x 8 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01
columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01-14         0.007371         0.000039             -1             1
#     2000-04-14        -0.000752         0.006967              1            -1
#     2000-07-17         0.004342        -0.014049             -1             1
#     2000-10-16        -0.004938         0.010031              1            -1
#     2001-01-16        -0.008202        -0.010039             -1             1
#     ...                     ...              ...            ...           ...
#     2024-10-15        -0.000452         0.003187              1            -1
#     2025-01-15        -0.004528         0.004879              2            -2
#     2025-04-14        -0.013143        -0.000357              2            -2
#     2025-07-15        -0.010330        -0.006009              2            -2
#     2025-10-15        -0.001583         0.004267              2            -2
#
#     [104 rows x 4 columns],
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -1.3186009399204193,
#     'pnl_mean_mom_SP': -0.00020162093882575218,
#     'pnl_std_mom_SP': 0.020277389125468417,
#     'sr_daily_mom_SP': -0.009943140982214329,
#     'sr_annual_mom_SP': -0.15784246973876173,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 1.3186009399204193,
#     'pnl_mean_mr_SP': 0.00020162093882575218,
#     'pnl_std_mr_SP': 0.020277389125468417,
#     'sr_daily_mr_SP': 0.009943140982214329,
#     'sr_annual_mr_SP': 0.15784246973876173,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -1.2105952499203423,
#     'pnl_mean_mom_DOW': -0.00018510630732726947,
#     'pnl_std_mom_DOW': 0.019076920018012967,
#     'sr_daily_mom_DOW': -0.009703154762534354,
#     'sr_annual_mom_DOW': -0.15403280660662735,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 1.2105952499203423,
#     'pnl_mean_mr_DOW': 0.00018510630732726947,
#     'pnl_std_mr_DOW': 0.019076920018012967,
#     'sr_daily_mr_DOW': 0.009703154762534354,
#     'sr_annual_mr_DOW': 0.15403280660662735}},
#   'rbc_5cal_1999-12-31_2025-09-30_10lag_2lev': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  \
#    DATE
#    1999-12-31         0.007371         0.000039       -2       2
#    2000-03-31        -0.000752         0.006967        2      -2
#    2000-06-30         0.004342        -0.014049       -2       2
#    2000-09-29        -0.004938         0.010031        2      -2
#    2000-12-29        -0.008202        -0.010039       -2       2
#    ...                     ...              ...      ...     ...
#    2024-09-30        -0.000452         0.003187        2      -2
#    2024-12-31        -0.004528         0.004879        2      -2
#    2025-03-31        -0.013143        -0.000357        2      -2
#    2025-06-30        -0.010330        -0.006009        2      -2
#    2025-09-30        -0.001583         0.004267        2      -2
#
#                double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
#    DATE
#    1999-12-31                       1                      1             -2
#    2000-03-31                       1                      1              2
#    2000-06-30                       1                      1             -2
#    2000-09-29                       1                      1              2
#    2000-12-29                       1                      1             -2
#    ...                            ...                    ...            ...
#    2024-09-30                       1                      1              2
#    2024-12-31                       1                      1              2
#    2025-03-31                       1                      1              2
#    2025-06-30                       1                      1              2
#    2025-09-30                       1                      1              2
#
#                pos_final_mr
#    DATE
#    1999-12-31             2
#    2000-03-31            -2
#    2000-06-30             2
#    2000-09-29            -2
#    2000-12-29             2
#    ...                  ...
#    2024-09-30            -2
#    2024-12-31            -2
#    2025-03-31            -2
#    2025-06-30            -2
#    2025-09-30            -2
#
#    [104 rows x 8 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01-14         0.007371         0.000039             -2             2
#     2000-04-14        -0.000752         0.006967              2            -2
#     2000-07-17         0.004342        -0.014049             -2             2
#     2000-10-16        -0.004938         0.010031              2            -2
#     2001-01-16        -0.008202        -0.010039             -2             2
#     ...                     ...              ...            ...           ...
#     2024-10-15        -0.000452         0.003187              2            -2
#     2025-01-15        -0.004528         0.004879              2            -2
#     2025-04-14        -0.013143        -0.000357              2            -2
#     2025-07-15        -0.010330        -0.006009              2            -2
#     2025-10-15        -0.001583         0.004267              2            -2
#
#     [104 rows x 4 columns],
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -0.7428152268909516,
#     'pnl_mean_mom_SP': -0.00011358030992216385,
#     'pnl_std_mom_SP': 0.024366733948254532,
#     'sr_daily_mom_SP': -0.004661285758007793,
#     'sr_annual_mom_SP': -0.07399561743297493,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 0.7428152268909516,
#     'pnl_mean_mr_SP': 0.00011358030992216385,
#     'pnl_std_mr_SP': 0.024366733948254532,
#     'sr_daily_mr_SP': 0.004661285758007793,
#     'sr_annual_mr_SP': 0.07399561743297493,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -0.7655660336725354,
#     'pnl_mean_mom_DOW': -0.00011705902655543354,
#     'pnl_std_mom_DOW': 0.02313031005724313,
#     'sr_daily_mom_DOW': -0.005060849866073332,
#     'sr_annual_mom_DOW': -0.08033850100958746,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 0.7655660336725354,
#     'pnl_mean_mr_DOW': 0.00011705902655543354,
#     'pnl_std_mr_DOW': 0.02313031005724313,
#     'sr_daily_mr_DOW': 0.005060849866073332,
#     'sr_annual_mr_DOW': 0.08033850100958746}},
#   'rbc_5cal_1999-12-31_2025-09-30_10lag_2lev_dd': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  pos_mom_prev  \
#    DATE
#    1999-12-31         0.007371         0.000039       -2       2           0.0
#    2000-03-31        -0.000752         0.006967        2      -2          -2.0
#    2000-06-30         0.004342        -0.014049       -2       2           2.0
#    2000-09-29        -0.004938         0.010031        2      -2          -2.0
#    2000-12-29        -0.008202        -0.010039       -2       2           2.0
#    ...                     ...              ...      ...     ...           ...
#    2024-09-30        -0.000452         0.003187        2      -2          -2.0
#    2024-12-31        -0.004528         0.004879        2      -2           2.0
#    2025-03-31        -0.013143        -0.000357        2      -2           2.0
#    2025-06-30        -0.010330        -0.006009        2      -2           2.0
#    2025-09-30        -0.001583         0.004267        2      -2           2.0
#
#                pos_mr_prev  double_down_scalar_mom  double_down_scalar_mr  \
#    DATE
#    1999-12-31          0.0                       1                      1
#    2000-03-31          2.0                       1                      1
#    2000-06-30         -2.0                       1                      1
#    2000-09-29          2.0                       1                      1
#    2000-12-29         -2.0                       1                      1
#    ...                 ...                     ...                    ...
#    2024-09-30          2.0                       1                      1
#    2024-12-31         -2.0                       2                      2
#    2025-03-31         -2.0                       2                      2
#    2025-06-30         -2.0                       2                      2
#    2025-09-30         -2.0                       2                      2
#
#                pos_final_mom  pos_final_mr
#    DATE
#    1999-12-31             -2             2
#    2000-03-31              2            -2
#    2000-06-30             -2             2
#    2000-09-29              2            -2
#    2000-12-29             -2             2
#    ...                   ...           ...
#    2024-09-30              2            -2
#    2024-12-31              4            -4
#    2025-03-31              4            -4
#    2025-06-30              4            -4
#    2025-09-30              4            -4
#
#    [104 rows x 10 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01
columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01-31         0.007371         0.000039             -1             1
#     2000-04-28        -0.000752         0.006967              1            -1
#     2000-07-31         0.004342        -0.014049             -1             1
#     2000-10-30        -0.004938         0.010031              1            -1
#     2001-01-30        -0.008202        -0.010039             -1             1
#     ...                     ...              ...            ...           ...
#     2024-10-29        -0.000452         0.003187              1            -1
#     2025-01-30        -0.004528         0.004879              2            -2
#     2025-04-28        -0.013143        -0.000357              2            -2
#     2025-07-29        -0.010330        -0.006009              2            -2
#     2025-10-29        -0.001583         0.004267              2            -2
#
#     [104 rows x 4 columns],
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -1.4462613729886051,
#     'pnl_mean_mom_SP': -0.0002211408827199702,
#     'pnl_std_mom_SP': 0.020185779213749498,
#     'sr_daily_mom_SP': -0.010955280961823886,
#     'sr_annual_mom_SP': -0.17390969380695898,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 1.4462613729886051,
#     'pnl_mean_mr_SP': 0.0002211408827199702,
#     'pnl_std_mr_SP': 0.020185779213749498,
#     'sr_daily_mr_SP': 0.010955280961823886,
#     'sr_annual_mr_SP': 0.17390969380695898,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -1.4098060016269147,
#     'pnl_mean_mom_DOW': -0.0002155666669154304,
#     'pnl_std_mom_DOW': 0.019015459894552167,
#     'sr_daily_mom_DOW': -0.01133638986965491,
#     'sr_annual_mom_DOW': -0.17995961016227294,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 1.4098060016269147,
#     'pnl_mean_mr_DOW': 0.0002155666669154304,
#     'pnl_std_mr_DOW': 0.019015459894552167,
#     'sr_daily_mr_DOW': 0.01133638986965491,
#     'sr_annual_mr_DOW': 0.17995961016227294}},
#   'rbc_5cal_1999-12-31_2025-09-30_20lag_2lev': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  \
#    DATE
#    1999-12-31         0.007371         0.000039       -2       2
#    2000-03-31        -0.000752         0.006967        2      -2
#    2000-06-30         0.004342        -0.014049       -2       2
#    2000-09-29        -0.004938         0.010031        2      -2
#    2000-12-29        -0.008202        -0.010039       -2       2
#    ...                     ...              ...      ...     ...
#    2024-09-30        -0.000452         0.003187        2      -2
#    2024-12-31        -0.004528         0.004879        2      -2
#    2025-03-31        -0.013143        -0.000357        2      -2
#    2025-06-30        -0.010330        -0.006009        2      -2
#    2025-09-30        -0.001583         0.004267        2      -2
#
#                double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
#    DATE
#    1999-12-31                       1                      1             -2
#    2000-03-31                       1                      1              2
#    2000-06-30                       1                      1             -2
#    2000-09-29                       1                      1              2
#    2000-12-29                       1                      1             -2
#    ...                            ...                    ...            ...
#    2024-09-30                       1                      1              2
#    2024-12-31                       1                      1              2
#    2025-03-31                       1                      1              2
#    2025-06-30                       1                      1              2
#    2025-09-30                       1                      1              2
#
#                pos_final_mr
#    DATE
#    1999-12-31             2
#    2000-03-31            -2
#    2000-06-30             2
#    2000-09-29            -2
#    2000-12-29             2
#    ...                  ...
#    2024-09-30            -2
#    2024-12-31            -2
#    2025-03-31            -2
#    2025-06-30            -2
#    2025-09-30            -2
#
#    [104 rows x 8 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01-31         0.007371         0.000039             -2             2
#     2000-04-28        -0.000752         0.006967              2            -2
#     2000-07-31         0.004342        -0.014049             -2             2
#     2000-10-30        -0.004938         0.010031              2            -2
#     2001-01-30        -0.008202        -0.010039             -2             2
#     ...                     ...              ...            ...           ...
#     2024-10-29        -0.000452         0.003187              2            -2
#     2025-01-30        -0.004528         0.004879              2            -2
#     2025-04-28        -0.013143        -0.000357              2            -2
#     2025-07-29        -0.010330        -0.006009              2            -2
#     2025-10-29        -0.001583         0.004267              2            -2
#
#     [104 rows x 4 columns],
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -1.280012629182451,
#     'pnl_mean_mom_SP': -0.00019572058550190383,
#     'pnl_std_mom_SP': 0.024336957238600652,
#     'sr_daily_mom_SP': -0.008042114040101652,
#     'sr_annual_mom_SP': -0.1276646025919794,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 1.280012629182451,
#     'pnl_mean_mr_SP': 0.00019572058550190383,
#     'pnl_std_mr_SP': 0.024336957238600652,
#     'sr_daily_mr_SP': 0.008042114040101652,
#     'sr_annual_mr_SP': 0.1276646025919794,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -1.342304094375646,
#     'pnl_mean_mom_DOW': -0.00020524527436936482,
#     'pnl_std_mom_DOW': 0.02310371234125277,
#     'sr_daily_mom_DOW': -0.008883649144249847,
#     'sr_annual_mom_DOW': -0.14102355822262116,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 1.342304094375646,
#     'pnl_mean_mr_DOW': 0.00020524527436936482,
#     'pnl_std_mr_DOW': 0.02310371234125277,
#     'sr_daily_mr_DOW': 0.008883649144249847,
#     'sr_annual_mr_DOW': 0.14102355822262116}},
#   'rbc_5cal_1999-12-31_2025-09-30_20lag_2lev_dd': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  pos_mom_prev  \
#    DATE
#    1999-12-31         0.007371         0.000039       -2       2           0.0
#    2000-03-31        -0.000752         0.006967        2      -2          -2.0
#    2000-06-30         0.004342        -0.014049       -2       2           2.0
#    2000-09-29        -0.004938         0.010031        2      -2          -2.0
#    2000-12-29        -0.008202        -0.010039       -2       2           2.0
#    ...                     ...              ...      ...     ...           ...
#    2024-09-30        -0.000452         0.003187        2      -2          -2.0
#    2024-12-31        -0.004528         0.004879        2      -2           2.0
#    2025-03-31        -0.013143        -0.000357        2      -2           2.0
#    2025-06-30        -0.010330        -0.006009        2      -2           2.0
#    2025-09-30        -0.001583         0.004267        2      -2           2.0
#
#                pos_mr_prev  double_down_scalar_mom  double_down_scalar_mr  \
#    DATE
#    1999-12-31          0.0                       1                      1
#    2000-03-31          2.0                       1                      1
#    2000-06-30         -2.0                       1                      1
#    2000-09-29          2.0                       1                      1
#    2000-12-29         -2.0                       1                      1
#    ...                 ...                     ...                    ...
#    2024-09-30          2.0                       1                      1
#    2024-12-31         -2.0                       2                      2
#    2025-03-31         -2.0                       2                      2
#    2025-06-30         -2.0                       2                      2
#    2025-09-30         -2.0                       2                      2
#
#                pos_final_mom  pos_final_mr
#    DATE
#    1999-12-31             -2             2
#    2000-03-31              2            -2
#    2000-06-30             -2             2
#    2000-09-29              2            -2
#    2000-12-29             -2             2
#    ...                   ...           ...
#    2024-09-30              2            -2
#    2024-12-31              4            -4
#    2025-03-31              4            -4
#    2025-06-30              4            -4
#    2025-09-30              4            -4
#
#    [104 rows x 10 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2000-01-31         0.007371         0.000039             -2             2
#     2000-04-28        -0.000752         0.006967              2            -2
#     2000-07-31         0.004342        -0.014049             -2             2
#     2000-10-30        -0.004938         0.010031              2            -2
#     2001-01-30        -0.008202        -0.010039             -2             2
#     ...                     ...              ...            ...           ...
#     2024-10-29        -0.000452         0.003187              2            -2
#     2025-01-30        -0.004528         0.004879              4            -4
#     2025-04-28        -0.013143        -0.000357              4            -4
#     2025-07-29        -0.010330        -0.006009              4            -4
#     2025-10-29        -0.001583         0.004267              4            -4
#
#     [104 rows x 4 columns],
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -2.8925227459772103,
#     'pnl_mean_mom_SP': -0.0004422817654399404,
#     'pnl_std_mom_SP': 0.040371558427498996,
#     'sr_daily_mom_SP': -0.010955280961823886,
#     'sr_annual_mom_SP': -0.17390969380695898,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 2.8925227459772103,
#     'pnl_mean_mr_SP': 0.0004422817654399404,
#     'pnl_std_mr_SP': 0.040371558427498996,
#     'sr_daily_mr_SP': 0.010955280961823886,
#     'sr_annual_mr_SP': 0.17390969380695898,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -2.8196120032538294,
#     'pnl_mean_mom_DOW': -0.0004311333338308608,
#     'pnl_std_mom_DOW': 0.038030919789104334,
#     'sr_daily_mom_DOW': -0.01133638986965491,
#     'sr_annual_mom_DOW': -0.17995961016227294,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 2.8196120032538294,
#     'pnl_mean_mr_DOW': 0.0004311333338308608,
#     'pnl_std_mr_DOW': 0.038030919789104334,
#     'sr_daily_mr_DOW': 0.01133638986965491,
#     'sr_annual_mr_DOW': 0.17995961016227294}},
#   'rbc_5cal_1999-12-31_2025-09-30_30lag': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  \
#    DATE
#    1999-12-31         0.007371         0.000039       -1       1
#    2000-03-31        -0.000752         0.006967        1      -1
#    2000-06-30         0.004342        -0.014049       -1       1
#    2000-09-29        -0.004938         0.010031        1      -1
#    2000-12-29        -0.008202        -0.010039       -1       1
#    ...                     ...              ...      ...     ...
#    2024-09-30        -0.000452         0.003187        1      -1
#    2024-12-31        -0.004528         0.004879        1      -1
#    2025-03-31        -0.013143        -0.000357        1      -1
#    2025-06-30        -0.010330        -0.006009        1      -1
#    2025-09-30        -0.001583         0.004267        1      -1
#
#                double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
#    DATE
#    1999-12-31                       1                      1             -1
#    2000-03-31                       1                      1              1
#    2000-06-30                       1                      1             -1
#    2000-09-29                       1                      1              1
#    2000-12-29                       1                      1             -1
#    ...                            ...                    ...            ...
#    2024-09-30                       1                      1              1
#    2024-12-31                       1                      1              1
#    2025-03-31                       1                      1              1
#    2025-06-30                       1                      1              1
#    2025-09-30                       1                      1              1
#
#                pos_final_mr
#    DATE
#    1999-12-31             1
#    2000-03-31            -1
#    2000-06-30             1
#    2000-09-29            -1
#    2000-12-29             1
#    ...                  ...
#    2024-09-30            -1
#    2024-12-31            -1
#    2025-03-31            -1
#    2025-06-30            -1
#    2025-09-30            -1
#
#    [104 rows x 8 columns],
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     

#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 0.44322900806759213,
#     'pnl_mean_mr_DOW': 0.0005894002766856279,
#     'pnl_std_mr_DOW': 0.010850105162268408,
#     'sr_daily_mr_DOW': 0.05432207963617592,
#     'sr_annual_mr_DOW': 0.8623362805030053}},
#   'rbc_20cal_2022-12-31_2025-09-30_30lag_2lev': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  \
#    DATE
#    2023-03-31         0.004899        -0.009586       -2       2
#    2023-06-30         0.003779        -0.012050       -2       2
#    2023-09-29         0.006965        -0.001760       -2       2
#    2023-12-29         0.006906         0.003412       -2       2
#    2024-03-29         0.001661         0.002021        2      -2
#    2024-06-28         0.002803        -0.008123       -2       2
#    2024-09-30         0.003172         0.001516       -2       2
#    2024-12-31         0.000497         0.002025        2      -2
#    2025-03-31        -0.006620        -0.004371        2      -2
#    2025-06-30        -0.003335        -0.011946       -2       2
#    2025-09-30         0.000398         0.001961        2      -2
#
#                double_down_scalar_mom  double_down_scalar_mr  pos_final_mom  \
#    DATE
#    2023-03-31                       1                      1             -2
#    2023-06-30                       1                      1             -2
#    2023-09-29                       1                      1             -2
#    2023-12-29                       1                      1             -2
#    2024-03-29                       1                      1              2
#    2024-06-28                       1                      1             -2
#    2024-09-30                       1                      1             -2
#    2024-12-31                       1                      1              2
#    2025-03-31                       1                      1              2
#    2025-06-30                       1                      1             -2
#    2025-09-30                       1                      1              2
#
#                pos_final_mr
#    DATE
#    2023-03-31             2
#    2023-06-30             2
#    2023-09-29             2
#    2023-12-29             2
#    2024-03-29            -2
#    2024-06-28             2
#    2024-09-30             2
#    2024-12-31            -2
#    2025-03-31            -2
#    2025-06-30             2
#    2025-09-30            -2  ,
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2023-05-12         0.004899        -0.009586             -2             2
#     2023-08-14         0.003779        -0.012050             -2             2
#     2023-11-14         0.006965        -0.001760             -2             2
#     2024-02-13         0.006906         0.003412             -2             2
#     2024-05-10         0.001661         0.002021              2            -2
#     2024-08-12         0.002803        -0.008123             -2             2
#     2024-11-13         0.003172         0.001516             -2             2
#     2025-02-13         0.000497         0.002025              2            -2
#     2025-05-12        -0.006620        -0.004371              2            -2
#     2025-08-12        -0.003335        -0.011946             -2             2
#     2025-11-13         0.000398         0.001961              2            -2,
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -0.6382310457566633,
#     'pnl_mean_mom_SP': -0.0008487114970168395,
#     'pnl_std_mom_SP': 0.017790863092812508,
#     'sr_daily_mom_SP': -0.04770490855835534,
#     'sr_annual_mom_SP': -0.7572919461749104,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 0.6382310457566633,
#     'pnl_mean_mr_SP': 0.0008487114970168395,
#     'pnl_std_mr_SP': 0.017790863092812508,
#     'sr_daily_mr_SP': 0.04770490855835534,
#     'sr_annual_mr_SP': 0.7572919461749104,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -0.7144936882026283,
#     'pnl_mean_mom_DOW': -0.0009501245853758355,
#     'pnl_std_mom_DOW': 0.01580279585803945,
#     'sr_daily_mom_DOW': -0.06012382833462175,
#     'sr_annual_mom_DOW': -0.9544361858552873,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 0.7144936882026283,
#     'pnl_mean_mr_DOW': 0.0009501245853758355,
#     'pnl_std_mr_DOW': 0.01580279585803945,
#     'sr_daily_mr_DOW': 0.06012382833462175,
#     'sr_annual_mr_DOW': 0.9544361858552873}},
#   'rbc_20cal_2022-12-31_2025-09-30_30lag_2lev_dd': {'signals':             output_realised  output_forecast  pos_mom  pos_mr  pos_mom_prev  \
#    DATE
#    2023-03-31         0.004899        -0.009586       -2       2           0.0
#    2023-06-30         0.003779        -0.012050       -2       2          -2.0
#    2023-09-29         0.006965        -0.001760       -2       2          -2.0
#    2023-12-29         0.006906         0.003412       -2       2          -2.0
#    2024-03-29         0.001661         0.002021        2      -2          -2.0
#    2024-06-28         0.002803        -0.008123       -2       2           2.0
#    2024-09-30         0.003172         0.001516       -2       2          -2.0
#    2024-12-31         0.000497         0.002025        2      -2          -2.0
#    2025-03-31        -0.006620        -0.004371        2      -2           2.0
#    2025-06-30        -0.003335        -0.011946       -2       2           2.0
#    2025-09-30         0.000398         0.001961        2      -2          -2.0
#
#                pos_mr_prev  double_down_scalar_mom  double_down_scalar_mr  \
#    DATE
#    2023-03-31          0.0                       1                      1
#    2023-06-30          2.0                       2                      2
#    2023-09-29          2.0                       2                      2
#    2023-12-29          2.0                       2                      2
#    2024-03-29          2.0                       1                      1
#    2024-06-28         -2.0                       1                      1
#    2024-09-30          2.0                       2                      2
#    2024-12-31          2.0                       1                      1
#    2025-03-31         -2.0                       2                      2
#    2025-06-30         -2.0                       1                      1
#    2025-09-30          2.0                       1                      1
#
#                pos_final_mom  pos_final_mr
#    DATE
#    2023-03-31             -2             2
#    2023-06-30             -4             4
#    2023-09-29             -4             4
#    2023-12-29             -4             4
#    2024-03-29              2            -2
#    2024-06-28             -2             2
#    2024-09-30             -4             4
#    2024-12-31              2            -2
#    2025-03-31              4            -4
#    2025-06-30             -2             2
#    2025-09-30              2            -2  ,
#    'strategy': {'signals_actual':             output_realised  output_forecast  pos_final_mom  pos_final_mr
#     DATE
#     2023-05-12         0.004899        -0.009586             -2             2
#     2023-08-14         0.003779        -0.012050             -4             4
#     2023-11-14         0.006965        -0.001760             -4             4
#     2024-02-13         0.006906         0.003412             -4             4
#     2024-05-10         0.001661         0.002021              2            -2
#     2024-08-12         0.002803        -0.008123             -2             2
#     2024-11-13         0.003172         0.001516             -4             4
#     2025-02-13         0.000497         0.002025              2            -2
#     2025-05-12        -0.006620        -0.004371              4            -4
#     2025-08-12        -0.003335        -0.011946             -2             2
#     2025-11-13         0.000398         0.001961              2            -2,
#     'fig_pos_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_SP': -0.7993730437955542,
#     'pnl_mean_mom_SP': -0.0010629960688770667,
#     'pnl_std_mom_SP': 0.024419792778540797,
#     'sr_daily_mom_SP': -0.04353010193482018,
#     'sr_annual_mom_SP': -0.6910189455889546,
#     'fig_pos_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_SP': 0.7993730437955542,
#     'pnl_mean_mr_SP': 0.0010629960688770667,
#     'pnl_std_mr_SP': 0.024419792778540797,
#     'sr_daily_mr_SP': 0.04353010193482018,
#     'sr_annual_mr_SP': 0.6910189455889546,
#     'fig_pos_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mom_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mom_DOW': -0.8864580161351843,
#     'pnl_mean_mom_DOW': -0.0011788005533712557,
#     'pnl_std_mom_DOW': 0.021700210324536815,
#     'sr_daily_mom_DOW': -0.05432207963617592,
#     'sr_annual_mom_DOW': -0.8623362805030053,
#     'fig_pos_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'fig_pnl_cumsum_mr_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_mr_DOW': 0.8864580161351843,
#     'pnl_mean_mr_DOW': 0.0011788005533712557,
#     'pnl_std_mr_DOW': 0.021700210324536815,
#     'sr_daily_mr_DOW': 0.05432207963617592,
#     'sr_annual_mr_DOW': 0.8623362805030053}},
#   'bh_2022-12-31_2025-09-30': {'strategy': {'signals_actual': 1,
#     'fig_pnl_cumsum_SP': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_SP': 0.6161665432802396,
#     'pnl_mean_SP': 0.0008193704032981909,
#     'pnl_std_SP': 0.009488156608868883,
#     'sr_daily_SP': 0.0863571752738882,
#     'sr_annual_SP': 1.370877658204346,
#     'fig_pnl_cumsum_DOW': <Figure size 1200x600 with 1 Axes>,
#     'pnl_sum_DOW': 0.39851369808123105,
#     'pnl_mean_DOW': 0.0005299384282995093,
#     'pnl_std_DOW': 0.008418139621429453,
#     'sr_daily_DOW': 0.06295196470137929,
#     'sr_annual_DOW': 0.9993314588565965}}}}

# %%
main_results_sorted = {}

for window in windows:
    window_str = str(window[0]) + "_" + str(window[1])
    main_results_sorted[window_str] = {}
    
    pnls_spg = []
    pnls_spn = []
    srs_spg = []
    srs_spn = []
    pnls_dowg = []
    pnls_down = []
    srs_dowg = []
    srs_down = []
    
    for strategy in results[window_str].keys():
        if "bh" in strategy:
            pnls_spg.append([strategy, results[window_str][strategy]["strategy"]["pnl_sum_SP"]])
            pnls_spn.append([strategy, results[window_str][strategy]["strategy"]["pnl_sum_SP"]]) # Assumed g = n for BH
            srs_spg.append([strategy, results[window_str][strategy]["strategy"]["sr_annual_SP"]])
            srs_spn.append([strategy, results[window_str][strategy]["strategy"]["sr_annual_SP"]]) # Assumed g = n for BH
            
            pnls_dowg.append([strategy, results[window_str][strategy]["strategy"]["pnl_sum_DOW"]])
            pnls_down.append([strategy, results[window_str][strategy]["strategy"]["pnl_sum_DOW"]]) # Assumed g = n for BH
            srs_dowg.append([strategy, results[window_str][strategy]["strategy"]["sr_annual_DOW"]])
            srs_down.append([strategy, results[window_str][strategy]["strategy"]["sr_annual_DOW"]]) # Assumed g = n for BH
        else:
            pnls_spg.append([strategy + "_momg", results[window_str][strategy]["strategy"]["pnl_sum_momg_SP"]])
            pnls_spn.append([strategy + "_momn", results[window_str][strategy]["strategy"]["pnl_sum_momn_SP"]])
            pnls_spg.append([strategy + "_mrg", results[window_str][strategy]["strategy"]["pnl_sum_mrg_SP"]])
            pnls_spn.append([strategy + "_mrn", results[window_str][strategy]["strategy"]["pnl_sum_mrn_SP"]])
            srs_spg.append([strategy + "_momg", results[window_str][strategy]["strategy"]["sr_annual_momg_SP"]])
            srs_spn.append([strategy + "_momn", results[window_str][strategy]["strategy"]["sr_annual_momn_SP"]])
            srs_spg.append([strategy + "_mrg", results[window_str][strategy]["strategy"]["sr_annual_mrg_SP"]])
            srs_spn.append([strategy + "_mrn", results[window_str][strategy]["strategy"]["sr_annual_mrn_SP"]])

            pnls_dowg.append([strategy + "_momg", results[window_str][strategy]["strategy"]["pnl_sum_momg_DOW"]])
            pnls_down.append([strategy + "_momn", results[window_str][strategy]["strategy"]["pnl_sum_momn_DOW"]])
            pnls_dowg.append([strategy + "_mrg", results[window_str][strategy]["strategy"]["pnl_sum_mrg_DOW"]])
            pnls_down.append([strategy + "_mrn", results[window_str][strategy]["strategy"]["pnl_sum_mrn_DOW"]])
            srs_dowg.append([strategy + "_momg", results[window_str][strategy]["strategy"]["sr_annual_momg_DOW"]])
            srs_down.append([strategy + "_momn", results[window_str][strategy]["strategy"]["sr_annual_momn_DOW"]])
            srs_dowg.append([strategy + "_mrg", results[window_str][strategy]["strategy"]["sr_annual_mrg_DOW"]])
            srs_down.append([strategy + "_mrn", results[window_str][strategy]["strategy"]["sr_annual_mrn_DOW"]])
    
    main_results_sorted[window_str]["pnls_spg_sorted"] = sorted(pnls_spg, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["pnls_spn_sorted"] = sorted(pnls_spn, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["srs_spg_sorted"] = sorted(srs_spg, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["srs_spn_sorted"] = sorted(srs_spn, key=lambda x: x[1], reverse=True)
    
    main_results_sorted[window_str]["pnls_dowg_sorted"] = sorted(pnls_dowg, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["pnls_down_sorted"] = sorted(pnls_down, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["srs_dowg_sorted"] = sorted(srs_dowg, key=lambda x: x[1], reverse=True)
    main_results_sorted[window_str]["srs_down_sorted"] = sorted(srs_down, key=lambda x: x[1], reverse=True)

# %%
main_results_sorted.keys()
# Out:
# dict_keys(['1999-12-31_2025-09-30', '1999-12-31_2007-12-31', '2007-12-31_2009-12-31', '2009-12-31_2019-12-31', '2019-12-31_2022-12-31', '2022-12-31_2025-09-30'])

# %%
main_results_sorted["1999-12-31_2025-09-30"]["pnls_sp_sorted"]
# Out:
# [['rbc_10cal_1999-12-31_2025-09-30_30lag_2lev_dd_mr', 3.9755539941841445],
#  ['rbc_5cal_1999-12-31_2025-09-30_30lag_2lev_dd_mr', 3.695777153533932],
#  ['rbc_10cal_1999-12-31_2025-09-30_20lag_2lev_dd_mr', 3.2078547049536],
#  ['rbc_5cal_1999-12-31_2025-09-30_20lag_2lev_dd_mr', 2.8925227459772103],
#  ['rbc_5cal_1999-12-31_2025-09-30_10lag_2lev_dd_mr', 2.6372018798408385],
#  ['rbc_10cal_1999-12-31_2025-09-30_10lag_2lev_dd_mr', 2.4748099156563503],
#  ['rbc_10cal_1999-12-31_2025-09-30_30lag_2lev_mr', 2.3268963552108834],
#  ['bh_1999-12-31_2025-09-30', 2.0262566792516465],
#  ['rbc_10cal_1999-12-31_2025-09-30_30lag_dd_mr', 1.9877769970920722],
#  ['rbc_5cal_1999-12-31_2025-09-30_30lag_2lev_mr', 1.9655817727863252],
#  ['rbc_5cal_1999-12-31_2025-09-30_30lag_dd_mr', 1.847888576766966],
#  ['rbc_10cal_1999-12-31_2025-09-30_20lag_2lev_mr', 1.841518941006284],
#  ['rbc_10cal_1999-12-31_2025-09-30_20lag_dd_mr', 1.6039273524768],
#  ['rbc_5cal_1999-12-31_2025-09-30_20lag_dd_mr', 1.4462613729886051],
#  ['rbc_5cal_1999-12-31_2025-09-30_10lag_dd_mr', 1.3186009399204193],
#  ['rbc_5cal_1999-12-31_2025-09-30_20lag_2lev_mr', 1.280012629182451],
#  ['rbc_10cal_1999-12-31_2025-09-30_10lag_dd_mr', 1.2374049578281752],
#  ['rbc_10cal_1999-12-31_2025-09-30_30lag_mr', 1.1634481776054417],
#  ['rbc_10cal_1999-12-31_2025-09-30_10lag